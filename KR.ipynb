# %%
#!/usr/bin/env python

import pandas as pd
import networkx as nx
from networkx.algorithms.bipartite.matrix import biadjacency_matrix
import numpy as np
from sklearn.metrics import precision_recall_curve, auc
import random
from sklearn import metrics
import time
import matplotlib.pyplot as plt
from scipy.linalg import inv
from joblib import Parallel, delayed
from sklearn.utils import parallel_backend
from itertools import product
from sklearn.metrics import roc_auc_score
from scipy.spatial.distance import cdist
random.seed(1949) # for dataset split
np.random.seed(1949) # for matrix initialization

# %% [markdown]
# This file is for the study of ADRs prediction using KR. After the function in section 1 run, nested CV, CV and result of test set in section 2 can be ran separately.

# %% [markdown]
# ## 1. Define the functions used for KR

# %%
def option(str):
    global methodOption
    methodOption = str

# %% [markdown]
# ### Function of Kernel Regression

# %%
def KernelRegression(matrix,feature_matrix1,feature_matrix2,idx_train,idx_test,l1,l2,s):
    sigma = s
    lmd1 = l1
    lmd2 = l2
        
    X1 = np.array(feature_matrix1[idx_train, :].copy()).tolist()
    X_new1 = np.array(feature_matrix1[idx_test, :].copy()).tolist()
    X2 = np.array(feature_matrix2[idx_train, :].copy()).tolist()
    X_new2 = np.array(feature_matrix2[idx_test, :].copy()).tolist()
    y = matrix[:, idx_train].copy()
    Y = pd.DataFrame(y.T.copy())
    # y_new = matrix[:, idx_test].copy()
    matrix_new = (matrix.copy()).astype(float)


    distance1 = cdist(X_new1, X1)**2
    distance2 = cdist(X_new2, X2)**2

    kernel1 = np.exp(-distance1/sigma**2)
    kernel2 = np.exp(-distance2/sigma**2)

    similarity1 = cdist(X1, X1)**2
    similarity2 = cdist(X2, X2)**2

    K1 = pd.DataFrame(np.exp(-similarity1/sigma**2))
    K2 = pd.DataFrame(np.exp(-similarity2/sigma**2))

    n = len(idx_train) # size of known drug

    
    if methodOption == "KR1":
        Lmd = np.diag(np.ones(n)*lmd1)
        W = inv(K1.dot(K1)+Lmd).dot(K1.dot(Y))
        y_new = kernel1.dot(W)
    elif methodOption == "KR2":
        Lmd = np.diag(np.ones(n)*lmd1)
        # print(Lmd)
        # print(K2.dot(K2)+Lmd)
        W = inv(K2.dot(K2)+Lmd).dot(K2.dot(Y))
        y_new = kernel2.dot(W)
    elif methodOption == "KR1&KR2":
        c1 = 0.5
        c2 = 0.5
        Lmd = np.diag(np.ones(n)*lmd1)
        K = c1*K1 + c2*K2
        W = inv(K.dot(K)+Lmd).dot(K.dot(Y))
        y_new = (c1*kernel1+c2*kernel2).dot(W)
    elif methodOption == "MKR":
        K = pd.concat([K1, K2], axis = 0).copy()
        KT = pd.concat([K1, K2], axis = 1).copy()
        KY = pd.concat([K1.dot(Y), K2.dot(Y)], axis = 0).copy()
        lmd1Vector = np.ones(n)*lmd1
        lmd2Vector = np.ones(n)*lmd2
        Lmd = np.diag(np.hstack([lmd1Vector, lmd2Vector]))
        W = inv(K.dot(KT)+Lmd).dot(KY)
        W1 = W[0:n, :].copy()
        W2 = W[n:2*n, :].copy()

        y_new = (kernel1.dot(W1) + kernel2.dot(W2))

    matrix_new[:, idx_test] = y_new.T
    return matrix_new

# %% [markdown]
# ### Function for generating features for common drugs

# %%
def FeaturePreprocess(df_all, drug_nodes):
    
    drug_nodes_df = np.intersect1d(df_all.index, drug_nodes)
    df = df_all.loc[drug_nodes_df]
    _, q = df.shape
    drug_nodes_diff = np.setdiff1d(drug_nodes, (df.index).tolist())
    n = len(drug_nodes_diff)
    df_diff = pd.DataFrame(np.zeros(n*q).reshape(n,q))
    df_diff.index = drug_nodes_diff
    df_diff.columns = df.columns
    df_all = pd.concat([df, df_diff], axis = 0)
    featureMat = df_all.loc[drug_nodes]
    return np.array(featureMat)

# %% [markdown]
# ### Function for cross validation and nested cross validation

# %%
def fold(IDX1,IDX2,feature_matrix1,feature_matrix2,matrix,l1,l2,s):
    # IDX1 target index, need to be evaluated
    # IDX2 test index, masked

    pr_auc_all = 0
    roc_auc_all = 0


    print('First few target index:', IDX1[0:10])
    print('First few mask index:', IDX2[0:10])

    target_idx = IDX1
    mask_idx = IDX2
    Ground_Truth = matrix.copy()
    side_effects_drug_relation_copy = matrix.copy()

    # target_idx = IDX2
    ### making all the links to predict as 0 ###############    
    for i in range(len(mask_idx)):
        side_effects_drug_relation_copy[:, mask_idx[i]] = 0
    
    m,n = side_effects_drug_relation_copy.shape

    drug_idx = list(range(n))
    existing_drug_idx = np.setdiff1d(drug_idx, mask_idx)

    print(methodOption + ' starts:')
    # real_stdout = sys.stdout
    # sys.stdout = open(os.devnull, "w")
    side_effects_drug_relation_fact = KernelRegression(matrix=matrix,\
        feature_matrix1=feature_matrix1,feature_matrix2=feature_matrix2,idx_train=existing_drug_idx,idx_test=target_idx,l1=l1,l2=l2,s=s)
    # sys.stdout = real_stdout
    print(methodOption + ' ends:')


    score = side_effects_drug_relation_fact.copy()


    print("proportion of ground truth:", sum(Ground_Truth[:, target_idx].ravel())/(Ground_Truth[:, target_idx].shape[0]*Ground_Truth[:, target_idx].shape[1]))

    print('---evaluation---')

    prec, recall, threshold = precision_recall_curve(Ground_Truth[:, target_idx].ravel(), score[:, target_idx].ravel())
    pr_auc_all = auc(recall, prec)
    roc_auc_all = roc_auc_score(Ground_Truth[:, target_idx].ravel(), score[:, target_idx].ravel())


    print("-----")

    print("AUC-PR all:", pr_auc_all)

    print("-----")

    print("AUC-ROC all:", roc_auc_all)


    return pr_auc_all, roc_auc_all

# %%
def innerfold(IDX1,IDX2,feature_matrix1,feature_matrix2,matrix,l1,l2,s):
    # IDX1 target index, need to be evaluated
    # IDX2 test index, masked

    print('First few target index:', IDX1[0:10])
    print('First few mask index:', IDX2[0:10])

    target_idx = IDX1
    mask_idx = IDX2
    Ground_Truth = matrix.copy()
    side_effects_drug_relation_copy = matrix.copy()

    # target_idx = IDX2
    ### making all the links to predict as 0 ###############    
    for i in range(len(mask_idx)):
        side_effects_drug_relation_copy[:, mask_idx[i]] = 0
    
    m,n = side_effects_drug_relation_copy.shape

    drug_idx = list(range(n))
    existing_drug_idx = np.setdiff1d(drug_idx, mask_idx)

    print(methodOption + ' starts:')
    # real_stdout = sys.stdout
    # sys.stdout = open(os.devnull, "w")
    side_effects_drug_relation_fact = KernelRegression(matrix=matrix,\
        feature_matrix1=feature_matrix1,feature_matrix2=feature_matrix2,idx_train=existing_drug_idx, idx_test=target_idx,l1=l1,l2=l2,s=s)
    # sys.stdout = real_stdout
    print(methodOption + ' ends:')

    score = side_effects_drug_relation_fact.copy()

    print("proportion of ground truth:", sum(Ground_Truth[:, target_idx].ravel())/(Ground_Truth[:, target_idx].shape[0]*Ground_Truth[:, target_idx].shape[1]))

    print('---evaluation---')
  
    pr_auc_all = 0
    roc_auc_all = 0

    prec, recall, threshold = precision_recall_curve(Ground_Truth[:, target_idx].ravel(), score[:, target_idx].ravel())
    pr_auc_all = auc(recall, prec)

    print("-----")

    print("AUC-PR all:", pr_auc_all)

    print("-----")


    return pr_auc_all, roc_auc_all

# %%
def plotfold(IDX1,IDX2,feature_matrix1,feature_matrix2,matrix,l1,l2,s):
    # IDX1 target index, need to be evaluated
    # IDX2 test index, masked


    print('First few target index:', IDX1[0:10])
    print('First few mask index:', IDX2[0:10])

    target_idx = IDX1
    mask_idx = IDX2
    Ground_Truth = matrix.copy()
    side_effects_drug_relation_copy = matrix.copy()

    # target_idx = IDX2
    ### making all the links to predict as 0 ###############    
    for i in range(len(mask_idx)):
        side_effects_drug_relation_copy[:, mask_idx[i]] = 0
    
    m,n = side_effects_drug_relation_copy.shape

    drug_idx = list(range(n))
    existing_drug_idx = np.setdiff1d(drug_idx, mask_idx)


    print(methodOption + ' starts:')
    side_effects_drug_relation_fact = KernelRegression(matrix=matrix,\
        feature_matrix1=feature_matrix1,feature_matrix2=feature_matrix2,idx_train=existing_drug_idx,idx_test=target_idx,l1=l1,l2=l2,s=s)
    print(methodOption + ' ends:')


    score = side_effects_drug_relation_fact.copy()
    

    print("proportion of ground truth:", sum(Ground_Truth[:, target_idx].ravel())/(Ground_Truth[:, target_idx].shape[0]*Ground_Truth[:, target_idx].shape[1]))

    print('---evaluation---')

    prec, recall, prthreshold = precision_recall_curve(Ground_Truth[:, target_idx].ravel(), score[:, target_idx].ravel())
    pr_auc_all = auc(recall, prec)
    
    fpr, tpr, rocthreshold = metrics.roc_curve(Ground_Truth[:, target_idx].ravel(), score[:, target_idx].ravel())
    roc_auc_all = auc(fpr, tpr)

    print("-----")

    print("AUC-PR all:", pr_auc_all)

    print("-----")

    print("AUC-ROC all:", roc_auc_all)

    print("-----")

    Out1 = pd.DataFrame([prec, recall, prthreshold])
    Out2 = pd.DataFrame([fpr, tpr, rocthreshold])
    return Out1, Out2

# %% [markdown]
# ### Function for assigning arguments of CV and nested CV, as well as finding the best hyperparameters

# %%
def setvar_tune(size):
# set var for hyper pars tuning size is the hyper par size ALL_...

    global ALL_AUCPR_all
    global ALL_AUROC_all

    ALL_AUCPR_all = np.zeros(size)
    ALL_AUROC_all = np.zeros(size)

# %%
def setvar_cv(FOLDS):
# set var for cv 

    global AUC_roc_all
    global AUC_pr_all
    
    AUC_roc_all = np.zeros(FOLDS)
    AUC_pr_all = np.zeros(FOLDS)

# %%
def asgvar_tune(idx, results):
    # assign var for cv from results
    # f: size of hyper pars

    ALL_AUCPR_all[idx] = results[0]
    ALL_AUROC_all[idx] = results[1]

# %%
def asgvar_cv(f, results):
    # assign var for cv from results
    # f: size of hyper pars

    AUC_pr_all[f] = results[0]
    AUC_roc_all[f] = results[1]

# %%
def tuning_results(tuneVar):
    idx = np.argmax(ALL_AUCPR_all)
    Var = tuneVar[idx]
    Value = ALL_AUCPR_all[idx]

    print("best hyperpar: ", Var)
    print("AUPRC: ", Value)

    
    return Var, Value

# %%
def setvar_besttune(innerfolds):
    global besttunevalue
    global besttunevar
    besttunevalue = np.zeros(innerfolds) # best metric value
    besttunevar = np.zeros(innerfolds) # the value of best var
    besttunevar = besttunevar.tolist()

# %%
def asg_besttune(f, value, var):
    besttunevalue[f] = value
    besttunevar[f] = var

# %%
def besttune():
    idx = np.argmax(besttunevalue)
    value = besttunevalue[idx]
    var = besttunevar[idx]
    return value, var

# %%
def cv_results():
    
    print("Mean AUC_pr_all", AUC_pr_all.mean()," ", "Standard Deviation:", AUC_pr_all.std())
    print("Mean AUC_roc_all", AUC_roc_all.mean()," ", "Standard Deviation:", AUC_roc_all.std())
    print("-----------")
    results = np.array([AUC_pr_all, AUC_roc_all])

    return results

# %% [markdown]
# ### Function for parallel computation

# %%
def tuning_loop(innermatrix, idx_train_inner, idx_test_inner, feature_matrix_inner1, feature_matrix_inner2, hyperparList, i):
    
    l1,l2,s = hyperparList[i]
    idx_target_inner = idx_test_inner
    print('target size:', len(idx_target_inner))
    results = innerfold(idx_target_inner,idx_test_inner,feature_matrix1=feature_matrix_inner1,feature_matrix2=feature_matrix_inner2,matrix=innermatrix,l1=l1,l2=l2,s=s)
    asgvar_tune(i, results=results)
    print("------ lmd1: ", l1, "lmd1: ", l2, "sigma: ", s, "------")

# %% [markdown]
# ### Main function

# %%
def main(method_option,normalization=True,Validation=False,sets="intersect", l1=0.5, l2=0, s=0.5):
    random.seed(1949) # for dataset split
    np.random.seed(1949) # for matrix initialization
    option(method_option)

    df = pd.read_csv("data/side-effect-and-drug_name_upper.tsv",sep = "\t")


    drug_id = df["drugbank_id"] # put col of df in var
    drug_name = df["drugbank_name"]
    # drug_name = df["drugnames"]
    side_effect = df["side_effect_name"]
    
    edgelist1 = zip(side_effect, drug_name)
    ##making Biparite Graph##
    B = nx.DiGraph()
    B.add_nodes_from(side_effect,bipartite = 0)
    B.add_nodes_from(drug_name,bipartite = 1)
    B.add_edges_from(edgelist1)
    # B.add_weighted_edges_from(edgelist2)
    drug_nodes = {n for n, d in B.nodes(data=True) if d['bipartite']==1}
    side_effect_nodes = {n for n, d in B.nodes(data=True) if d['bipartite']==0}
    drug_nodes = list(drug_nodes)
    drug_nodes.sort()
    side_effect_nodes = list(side_effect_nodes)
    side_effect_nodes.sort()
    ###Getting the Bi-Adjacency matrix between side effects and drugs ###################
    matrix_all = biadjacency_matrix(B, row_order = side_effect_nodes, column_order = drug_nodes) # create biadjacency matrix for drug side effect graph
    matrix_all = matrix_all.A
    m_all,n_all = matrix_all.shape # number of side effect # number of drug
    
    
    ### Setting validation set / training set / testing set ###
    validate_sz = int(0.25 * n_all)
    IDX_all = list(range(n_all))
    random.shuffle(IDX_all)
    IDX_validate = sorted(IDX_all[0:validate_sz])
    print("first few validation set idx:")
    print(IDX_validate[0:10])
    IDX_validate_diff = np.setdiff1d(IDX_all, IDX_validate)
    matrix = matrix_all[:, IDX_validate_diff].copy()

    df1 = pd.read_csv("data/intersection_DGIdb_mat.tsv",sep = "\t")
    df2 = pd.read_csv("data/intersection_Fingerprint_mat.tsv",sep = "\t")
    featureMat1_all = FeaturePreprocess(df1, drug_nodes=drug_nodes)
    featureMat2_all = FeaturePreprocess(df2, drug_nodes=drug_nodes)
    featureMat1 = featureMat1_all[IDX_validate_diff, :].copy()
    featureMat2 = featureMat2_all[IDX_validate_diff, :].copy()
    
    
    non_zero_idx_union = np.hstack(np.where(~((featureMat1.sum(1) == 0) & (featureMat2.sum(1) == 0))))
    non_zero_idx_missing = np.hstack(np.where(~(~(featureMat1.sum(1) == 0) & ~(featureMat2.sum(1) == 0))))
    non_zero_idx_intersect = np.hstack(np.where(~(featureMat1.sum(1) == 0) & ~(featureMat2.sum(1) == 0)))
    if sets == "union":
        # union
        matrix = matrix[:, non_zero_idx_union].copy()
        featureMat1 = featureMat1[non_zero_idx_union, :].copy()
        featureMat2 = featureMat2[non_zero_idx_union, :].copy()
    elif sets == "intersect":
        # intersect
        non_zero_idx_intersect_all = np.hstack(np.where(~(featureMat1_all.sum(1) == 0) & ~(featureMat2_all.sum(1) == 0)))
    
        matrix_all = matrix_all[:, non_zero_idx_intersect_all].copy()
        featureMat1_all = featureMat1_all[non_zero_idx_intersect_all, :].copy()
        featureMat2_all = featureMat2_all[non_zero_idx_intersect_all, :].copy()
    
        matrix = matrix[:, non_zero_idx_intersect].copy()
        featureMat1 = featureMat1[non_zero_idx_intersect, :].copy()
        featureMat2 = featureMat2[non_zero_idx_intersect, :].copy()
    
        IDX_validate = np.setdiff1d(non_zero_idx_intersect_all, IDX_validate_diff)
        IDX_validate_diff = np.setdiff1d(non_zero_idx_intersect_all, IDX_validate)
    
        drug_nodes_intersect_all = np.array(drug_nodes)[non_zero_idx_intersect_all]
        drug_nodes_intersect_validate_diff = np.array(drug_nodes)[IDX_validate_diff]
        drug_nodes_intersect_validate = np.array(drug_nodes)[IDX_validate]
    
        IDX_validate = np.array([x for x in range(len(drug_nodes_intersect_all)) if drug_nodes_intersect_all[x] in drug_nodes_intersect_validate])
        IDX_validate_diff = np.array([x for x in range(len(drug_nodes_intersect_all)) if drug_nodes_intersect_all[x] in drug_nodes_intersect_validate_diff])
    

    m,n = matrix.shape # number of side effect # number of drug


    random.seed(1949) # for dataset split
    np.random.seed(1949) # for matrix initialization
    start_time = time.time()



    FOLDS = 5
    innerFOLDS = 4
    ####for test sets####
    setvar_cv(FOLDS)

    sz = n
    IDX = list(range(sz))
    fsz = int(sz/FOLDS)
    random.shuffle(IDX)
    IDX = np.array(IDX)
    offset = 0

    innersz = sz - fsz
    innerIDX = list(range(innersz))
    random.shuffle(innerIDX)
    innerIDX = np.array(innerIDX)
    innerfsz = int(innersz / innerFOLDS)
    inneroffset = 0
    # setvar_cv(FOLDS=FOLDS)

    if Validation == "nested_cv":
        for f in range(FOLDS):  # range(FOLDS):
            offset = 0 + fsz*f 
            idx_test = IDX[offset:offset + fsz]
    
            idx_train = IDX[np.setdiff1d(np.arange(len(IDX)), np.arange(offset,offset + fsz))]
            print("Fold:",f)
                
            innermatrix = matrix[:, idx_train]
    
            innerfeatureMat1 = featureMat1[idx_train, :].copy()
            innerfeatureMat2 = featureMat2[idx_train, :].copy()

    
            setvar_besttune(innerFOLDS)
    
            for innerf in range(innerFOLDS):
                inneroffset = 0 + innerf*innerfsz
                idx_test_inner = innerIDX[inneroffset:inneroffset + innerfsz]
                idx_train_inner = innerIDX[np.array(np.setdiff1d(np.arange(len(idx_train)), np.arange(inneroffset,inneroffset + innerfsz)))]
    
                print("Inner Fold:", innerf)

                lmd1 = (10**np.arange(-2, 4, 1, dtype=float)).tolist()
                if method_option == "MKR":
                    lmd2 = (10**np.arange(-2, 4, 1, dtype=float)).tolist()
                else:
                    lmd2 = (np.arange(0, 1, 1, dtype=float)).tolist()
                sigma = (10**np.arange(-1, 2, 1, dtype=float)).tolist()
                hyperparList = list(product(lmd1, lmd2, sigma))

    
                setvar_tune(len(hyperparList))
    
                with parallel_backend('threading'):
                    Parallel(n_jobs=50)(delayed(tuning_loop)(innermatrix = innermatrix, idx_train_inner = idx_train_inner, \
                            idx_test_inner = idx_test_inner, feature_matrix_inner1 = innerfeatureMat1, feature_matrix_inner2 = innerfeatureMat2, \
                                hyperparList = hyperparList, i = i) \
                                    for i in range(len(hyperparList)))

                hyperpars, evalValue = tuning_results(tuneVar=hyperparList)
    
    
                asg_besttune(innerf, value=evalValue, var=hyperpars)
                    
            _, bestHyperPars = besttune()
    
            print("--- tuning end ---")
            l1, l2, s = bestHyperPars
            idx_target = idx_test
            print('target size:', len(idx_target))
    
            print("------ lmd1: ", l1, "lmd1: ", l2, "sigma: ", s, "------")

    
            results = fold(idx_target,idx_test,featureMat1,featureMat2,matrix,l1=l1,l2=l2,s=s)
            asgvar_cv(f=f, results=results)

        out = cv_results()
        return out

    elif Validation == "cv":
        
        setvar_besttune(FOLDS)

        for f in range(FOLDS):
            offset = 0 + fsz*f 
            idx_test = IDX[offset:offset + fsz]
            idx_train = IDX[np.setdiff1d(np.arange(len(IDX)), np.arange(offset,offset + fsz))]

            print("Fold:", f)


            lmd1 = (10**np.arange(-2, 4, 1, dtype=float)).tolist()
            if method_option == "MKR":
                lmd2 = (10**np.arange(-2, 4, 1, dtype=float)).tolist()
            else:
                lmd2 = (np.arange(0, 1, 1, dtype=float)).tolist()
            sigma = (10**np.arange(-1, 2, 1, dtype=float)).tolist()
            hyperparList = list(product(lmd1, lmd2, sigma))

            setvar_tune(len(hyperparList))
    
            with parallel_backend('threading'):
                Parallel(n_jobs=50)(delayed(tuning_loop)(innermatrix = matrix, idx_train_inner = idx_train, \
                        idx_test_inner = idx_test, feature_matrix_inner1 = featureMat1, feature_matrix_inner2 = featureMat2, \
                            hyperparList = hyperparList, i = i) \
                                for i in range(len(hyperparList)))
    
            hyperpars, evalValue = tuning_results(tuneVar=hyperparList)
            asg_besttune(f, value=evalValue, var=hyperpars)

    
        print("--- tuning end ---")
        # cv_results()
        _, bestHyperPars = besttune()
    elif Validation == "Validation":

        # validation
        idx_test = IDX_validate
        idx_train = IDX_validate_diff
        idx_target = idx_test
        print('target size:', len(idx_target))
        print("------ lmd1: ", l1, "lmd1: ", l2, "sigma: ", s, "------")
        results = fold(idx_target,idx_test,featureMat1_all,featureMat2_all,matrix_all,l1=l1,l2=l2,s=s)
        return
    elif Validation == "plot":

        # validation
        idx_test = IDX_validate
        idx_train = IDX_validate_diff
        idx_target = idx_test
        print('target size:', len(idx_target))
        print("------ lmd1: ", l1, "lmd1: ", l2, "sigma: ", s, "------")
        pr, roc = plotfold(idx_target,idx_test,featureMat1_all,featureMat2_all,matrix_all,l1=l1,l2=l2,s=s)
        return pr, roc

# %% [markdown]
# ## 2. Nested CV and CV of KR

# %% [markdown]
# ### 2.1. Nested CV

# %% [markdown]
# Running the nested CV for feature DGI

# %%
results_KR1 = main(method_option="KR1",Validation="nested_cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# Inner Fold: 0
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 ends:KR1 ends:
#
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.02418288980175031proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.40303101589913193
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.08765387254974549
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# -----
# AUC-PR all: 0.062084131388398175
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.062265650661429875
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.02418288980175031
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.34262514846465997
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09903619891290835
# -----
# ------ lmd1:  ---evaluation---
# 1.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.07132924262415957
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.10594728717226523
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.39626555449198875
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation--------
# AUC-PR all: 0.3809456557505946
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#
# -----
# AUC-PR all: 0.10715401989709401
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# ----------
# AUC-PR all: 0.08331654651753866
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.07091007903823839
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3677240642486148
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08262294433430933
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.06207056286531084
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3373453673490417
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0678283360926431
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.40303101589913193
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index:
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# [397 369  92 268 306 322 110 284 140 210]target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115target size: 115target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 ends:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:KR1 starts:
#
#
# KR1 starts:
# KR1 starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# KR1 ends:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# proportion of ground truth:proportion of ground truth: 0.024706275188892426
#  0.024706275188892426
# ---evaluation---
# ---evaluation---KR1 ends:
#
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.08716013067076514
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1 starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.053523514160232266
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.057377414989489756
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.053484749833674836
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# -----KR1 ends:
#
# AUC-PR all: 0.08536608206630997
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3345560485031557
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# KR1 ends:
# KR1 ends:proportion of ground truth:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
#  0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.07085369459327318
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.05348556253547139
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4054353627698138
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.055900909993696485
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.36164628552561695
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07269782410926078
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3292992482072535
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.41700376005804074
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# -----
# AUC-PR all: 0.05786379751734526
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07929700973992583
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.07058600284022447
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3892289014200351
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.41700376005804074
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
# KR1 starts:
#
# KR1 ends:KR1 ends:
# KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1 ends:KR1 starts:
# KR1 starts:
#
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1 starts:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1 ends:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation--------
# AUC-PR all: 0.12532377941874848
# -----
# ------ lmd1:
# 10.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.10650860104821162
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# -----
# -----
# AUC-PR all:AUC-PR all: 0.45138584509568097
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#  0.10510355891154674
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: -----
# AUC-PR all: 0.1387959994847602
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# 0.028759794062604347
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.10641720198206475
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# proportion of ground truth:KR1 ends:
#  0.028759794062604347
# ---evaluation---
# KR1 ends:KR1 ends:
#
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.13840998327602683
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.44298525171095704
# -----
# ------ lmd1:  1.0 proportion of ground truth: 0.028759794062604347
# ---evaluation---
# lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all:KR1 ends: 0.11963688437737113
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
#
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.10054449066768784
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.42619123471844805
# -----
# ------ lmd1:  0.01----- lmd1:
#  AUC-PR all:0.0  sigma:  10.0 ------
# 0.11877501981706395
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.38194443346117113
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.10056335739056414
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10057129286218999
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4069644251901402
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.37691219790746355
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.14101159508030792
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.45138584509568097
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1 ends:
# KR1 ends:
# proportion of ground truth: proportion of ground truth: 0.02572974987769555
# ---evaluation---KR1 ends:
# 0.02572974987769555
# ---evaluation---
#
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1 ends:
# proportion of ground truth:KR1 ends:
# proportion of ground truth:KR1 ends:
#  0.02572974987769555
# ---evaluation---
#  0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.07964708592680052
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# -----
# AUC-PR all: 0.0671507124656243
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:KR1 ends:proportion of ground truth:
# KR1 ends:0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
#
# -----
# AUC-PR all: 0.33321519296215996
# -----
# ------ lmd1:  1000.0  lmd1:  0.0 sigma:  10.0 ------
# 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.4027524008416848
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09454782762615846
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:-----
# AUC-PR all: 0.0713559630533401
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#  0.02572974987769555
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.06729285485620129
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07115564141714442
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3708059355868455
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.42354340304389276
# -----
# ------ lmd1:  1.0 lmd1:  proportion of ground truth: 0.02572974987769555
# ---evaluation---
# 0.0 sigma:  10.0 ------
# -----
# -----AUC-PR all: 0.10169567008680966
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.3390822697470371
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:KR1 ends:
#  0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.10162119317299591
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07910022917695256
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.4352660346504161
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.06729094357992654
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.0683380910748522
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.08330717080608585
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4352660346504161
# --- tuning end ---
# target size: 115
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.4180512365992356
# -----
# AUC-ROC all: 0.8889455664919665
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Fold: 1
# Inner Fold: 0
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size:target size: 115
# First few target index:  115
# First few target index: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# [327  39 166 367  17 387 158  45 293  27]
# First few mask index: target size: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:[327  39 166 367  17 387 158  45 293  27] 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
#  target size:115
# First few target index:  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27][327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 ends:
# KR1 starts:
# KR1 starts:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1 ends:
# KR1 ends:
# KR1 starts:
# KR1 ends:
# KR1 starts:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth:KR1 ends:
#  proportion of ground truth: 0.02529954883247785
# ---evaluation---
# 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1 starts:-----
# AUC-PR all:
#  0.10033271510774475
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# KR1 ends:
# KR1 ends:KR1 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
#
# KR1 ends:-----
# AUC-PR all: 0.09611132089441277
# -----
# ------ lmd1:  1.0-----
# AUC-PR all: 0.4036725525272181
# -----
# ------ lmd1:  0.01 lmd1: KR1 ends: KR1 ends:KR1 ends:
#
#
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
#  lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10073837551825454
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0
# ------
# -----
# AUC-PR all: 0.08669597819681962
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.00.0 sigma:  10.0 ------ ------
#
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785proportion of ground truth: 0.02529954883247785
# ---evaluation---
#
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.41389492762575697
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.34902133069195124
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.06647200177523133
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:proportion of ground truth: 0.02529954883247785
# ---evaluation---
#
# -----
# AUC-PR all:-----
# AUC-PR all:0.06656568455882968
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06806681378969497
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
#  0.37680773208267637
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3431741988563356
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# -----
# AUC-PR all: 0.07094965481190213
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.07073041040797773
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06647647076609493
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.4271986532424482
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08263798814278503
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08326826537801561
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4271986532424482
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 starts:KR1 ends:KR1 starts:
#
#
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1 starts:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth:KR1 ends:
# KR1 ends: 0.026847961980788496
# ---evaluation---
#
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1 starts:
# KR1 starts:
# KR1 ends:KR1 ends:-----
#
# KR1 ends:
#
# AUC-PR all: 0.10725517523796255
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1 ends:-----
# AUC-PR all: 0.10066447052327337
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
#
# KR1 ends:
# -----
# AUC-PR all: 0.3690085986062251
# -----
# ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.4230085083609174
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:proportion of ground truth: 0.026847961980788496
# ---evaluation---
#
# -----
# AUC-PR all: 0.40537159699350334
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:KR1 ends:
# KR1 ends:proportion of ground truth: 0.026847961980788496
# ---evaluation---
#
#
# KR1 ends:
# -----
# AUC-PR all: 0.34636806112616825
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.06721357674192592proportion of ground truth: 0.026847961980788496
# ---evaluation---
#
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.06925942227840662
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# ----------
# AUC-PR all:
# AUC-PR all:  0.08376971907515765
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# 0.3505555362099077
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.06302823148262493
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.08324706205273195
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# KR1 ends:
# AUC-PR all: 0.06317744997614241
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.0692234343159773
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3985866269686197
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08769158957062895
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.106852762679883
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.06304010073546923
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4230085083609174
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 starts:
# KR1 starts:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR1 starts:
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR1 starts:
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.420082242658263
# -----
# ------ lmd1: proportion of ground truth: 0.028399481273829952
# ---evaluation---
#  0.01 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
#
# KR1 ends:proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth:
# KR1 ends:
#  0.028399481273829952
# ---evaluation---
# KR1 ends:proportion of ground truth:
#  0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.09788205927615912
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.13311636978286276
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.10351578464108943
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# proportion of ground truth:AUC-PR all: 0.12928054645652032
# -----
# ------ lmd1: proportion of ground truth: 0.028399481273829952 1.0 lmd1:  0.0 sigma:  1.0 ------
#  0.028399481273829952
# ---evaluation---
#
# ---evaluation---
# KR1 ends:KR1 ends:
#
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# ----------
# AUC-PR all: 0.09789480266516706
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.1033350434267572
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.1008273393896949
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.1039433624484137
# -----
# ------ lmd1:  1000.0 lmd1: ----- 0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10494200063833177
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.11183014416012396
# -----
# ------ lmd1:  10.0----- lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.36317390397338256
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0978817224939558
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4454648882270383
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.4314894340897534
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.3932110893834397
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.36843417865118866
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1312625139820499
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4454648882270383
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size:  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115115
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:
# 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 starts:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.07899394211565128
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 ends:
# KR1 ends:KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.07934107914389696
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.40238876014394853
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09144092214886262
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07581945128418308
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:-----
# AUC-PR all: 0.11196646684851921
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends: 0.02280531461363442
# ---evaluation---
#
# -----
# AUC-PR all: 0.09721248150374494
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.33624647495915905
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.11320292877456865
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.4123830802804468
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 ends:
# KR1 ends:
# -----
# -----
# AUC-PR all: 0.34149763940474276
# -----
# ------ lmd1:  100.0 lmd1:  0.0 AUC-PR all:sigma:   10.00.09220349039389317
# -----------
#
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.11064111907061955
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.0762291715238117
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.0771090184186101
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# ...
# -----
# AUC-PR all: 0.40103789194046935
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# KR1 ends:KR1 ends:KR1 ends:
# 1000.0 lmd1:  0.0 sigma:  0.1 ------
#
#
# KR1 ends:proportion of ground truth: 0.026566855882649853
# ---evaluation---
#
# proportion of ground truth:proportion of ground truth:proportion of ground truth: 0.026566855882649853
# ---evaluation---
#  0.026566855882649853
# ---evaluation---
#  0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# proportion of ground truth:---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
#  0.026566855882649853
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.3389602074955594
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.06362799855644774
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.07985108748876316
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.1101629772207128
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1077299809402151
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07173969527520635
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3625678925103699
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07916955125225131
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:KR1 ends:
#  0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.33452043054359776
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.4108426926234739
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09873667374099422
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08461400888672821
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4108426926234739
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1 ends:KR1 starts:
#
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1 ends:proportion of ground truth: 0.02225242085154958
# ---evaluation---
#
# KR1 starts:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1 ends:
# KR1 starts:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1 ends:
# KR1 ends:
# KR1 ends:
# -----KR1 ends:
# AUC-PR all: 0.08953229846330604
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
#
# -----
# AUC-PR all: 0.10337607113561156
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.3634170533675905
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
#  0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.3572664322196464
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 KR1 ends:KR1 ends:
#
# -----------
# AUC-PR all: 0.3924817339074832
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.10180636383978853
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.0719137308384322
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:proportion of ground truth: 0.02225242085154958
# ---evaluation---
#
# -----
# AUC-PR all: 0.07227968879454238
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06778146673431407
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06741458676160106
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1 ends:
# KR1 ends:-----
# AUC-PR all: 0.39383950392536815
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#
# KR1 ends:-----
#
# AUC-PR all: 0.07186151272634167
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.08315967016592539
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.06742838974779004
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.3401977634920599
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.104543257063587
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3357109599230226
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08397739870050233
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.39383950392536815
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# First few target index:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 starts:
# proportion of ground truth:KR1 ends:
#  0.02655909052082282
# ---evaluation---
# KR1 starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 starts:
# KR1 ends:KR1 ends:KR1 ends:
#
#
# KR1 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1 starts:
# proportion of ground truth:proportion of ground truth:  0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# 0.02655909052082282proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.36148702392697907
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.4020435036422629
# -----
#  ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# 0.02655909052082282
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.10124672714106263
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.06570145454980786
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.08974009971882793
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09907831543114157
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:KR1 ends:-----
# AUC-PR all: 0.07042845862016288
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#
# proportion of ground truth:KR1 ends:
#
#  0.02655909052082282
# ---evaluation---
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.09229343292924849
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: ---evaluation---
# 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.3605593294617966
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# AUC-PR all: 0.06854488277944057
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.06971850763751528
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.36472790999013976
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.4121668869874985
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10094659392018819
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09012376960235254
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.38546314311163643
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.06569269763837016
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06570155253976412
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4121668869874985
# --- tuning end ---
# target size: 115
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4449297809124555
# -----
# AUC-ROC all: 0.8954327844559083
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Mean AUC_pr_all_mean: 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_mean 0.0   Standard Deviation: 0.0
# Mean Fmax_mean 0.0   Standard Deviation: 0.0
# Mean Smin_mean 0.0   Standard Deviation: 0.0
# Mean F1_mean 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all 0.43476363330936235   Standard Deviation: 0.009699203265284917
# Mean AUC_roc_all 0.8924227592404497   Standard Deviation: 0.0022379658798283996
# Mean AUC_pr_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn 0.0   Standard Deviation: 0.0
# Mean Fmax 0.0   Standard Deviation: 0.0
# Mean Smin 0.0   Standard Deviation: 0.0
# Mean F1 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_rd 0.0   Standard Deviation: 0.0
# Mean Fmax_rd 0.0   Standard Deviation: 0.0
# Mean Smin_rd 0.0   Standard Deviation: 0.0
# Mean F1_rd 0.0   Standard Deviation: 0.0

# %% [markdown]
# Running the nested CV for feature Chem

# %%
results_KR2 = main(method_option="KR2",Validation="nested_cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# Inner Fold: 0
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 starts:
# KR2 starts:KR2 starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# KR2 ends:
# KR2 starts:
# proportion of ground truth: KR2 starts:
# 0.02418288980175031
# ---evaluation---
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR2 ends:
# KR2 starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.3182237516161377
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.02418288980175031proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation--------KR2 ends:
#
#
# KR2 ends:
# AUC-PR all: 0.1360787371447943
# ----------
# AUC-PR all: 0.13335147452365126
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.13530923253702992
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
#
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:-----
# AUC-PR all: 0.14180598086478785
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
#  0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:KR2 ends: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# -----
# AUC-PR all: 0.3491940673956136
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.13607643884132725
# -----
# ------ lmd1: KR2 ends: 1.0
#  lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:-----
# -----
# AUC-PR all: 0.37957590988302753
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
#
# AUC-PR all: 0.13530923253702992
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.13352460826531645
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.3207705372087923
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.1331640137613655
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.13875904978121514
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.1360787371447943
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.13530923253702992
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.1375494902178638
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3819254494238152
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3469242966098116
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.3819254494238152
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index:target size: 115
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115 [397 369  92 268 306 322 110 284 140 210]
#
# First few target index:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# KR2 starts:
# KR2 starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth:KR2 ends:KR2 starts:
#
#  0.024706275188892426
# ---evaluation---
# KR2 ends:
# KR2 starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR2 ends:
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.17678662354900393
# -----
# ------ lmd1:  0.1 lmd1: ----- 0.0 sigma:  1.0 ------
# proportion of ground truth:KR2 ends:
#
# AUC-PR all: 0.21013104517465503
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
#  0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# KR2 ends:---evaluation---
#
# KR2 ends:
# -----proportion of ground truth: 0.024706275188892426
# ---evaluation---proportion of ground truth: 0.024706275188892426
# ---evaluation---
#
# AUC-PR all: 0.2104072099045698
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#
# -----
# AUC-PR all: 0.21042191200748125
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:KR2 ends:
#
# -----
# AUC-PR all: 0.3160801494773604
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.3919164854076803
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# KR2 ends:
# proportion of ground truth: KR2 ends:0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.37423854398003137
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
#
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.17635553642384838
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.33008728009642085
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:proportion of ground truth: 0.024706275188892426
# ---evaluation---
#  0.024706275188892426
# ---evaluation---
# -----proportion of ground truth: KR2 ends:0.024706275188892426
#
# ---evaluation---
#
# AUC-PR all: 0.2104072099045698
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.363699447760462
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.1765123041450153
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1763605711269014
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1779369887805733
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.33870288640174495
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.17715237661103478
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.21013104517465503
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.21013104517465503
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.3919164854076803
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# [409 406 371  86 278 416 265 164 252 213]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 ends:KR2 starts:
#
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR2 starts:
# KR2 ends:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR2 ends:proportion of ground truth: 0.028759794062604347
# ---evaluation---
#
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.36680991105778166-----
# KR2 ends:
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#
# AUC-PR all: 0.3052158063569555
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.21626613746455137
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3052158063569555
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3052158063569555
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:KR2 ends:
#
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR2 ends:KR2 ends:
#
# proportion of ground truth:proportion of ground truth:-----
# AUC-PR all: 0.2060360812120147  0.028759794062604347
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.028759794062604347
#
# ---evaluation---
# 0.3879358033491776---evaluation---
# proportion of ground truth: 0.028759794062604347
#
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.20604195662330765
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.3052158063569555
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3052158063569555
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.20683278539474584
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.3629993815240023
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.42057061565484377
# -----
# ------ lmd1:  1.0-----
# AUC-PR all: 0.39372787178029156
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#  lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.21832488266866476
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.4155636283920156
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.3052158063569555
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.21020256039215818
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.42057061565484377
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]target size:target size:target size:  115115
#
# First few target index:First few target index:  [309 216 444 217 248 437 178  23 187   8]115[309 216 444 217 248 437 178  23 187   8]
#
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# First few target index:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:KR2 ends:
#
# KR2 starts:
# KR2 starts:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR2 ends:
# KR2 ends:proportion of ground truth:KR2 starts:
#  0.02572974987769555
# ---evaluation---
#
# proportion of ground truth:KR2 ends: 0.02572974987769555
# ---evaluation---
# KR2 ends:
#
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR2 starts:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
#
# AUC-PR all: 0.16608007691399046
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:KR2 ends:
# KR2 starts:
#
# KR2 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.11059802922471222
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: proportion of ground truth:-----0.02572974987769555
# ---evaluation---
#  0.02572974987769555
# ---evaluation---
#
# AUC-PR all: 0.16608007691399046
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma: KR2 ends:
# KR2 ends: 0.1 ------
#
# KR2 ends:
# -----
# AUC-PR all: 0.32634510220558455
# -----
# ------ lmd1:  KR2 ends:
# 0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.35526468781522613
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:KR2 ends:
#
# proportion of ground truth:-----
# AUC-PR all: 0.30550263545238004
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#  0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.3167384028006561
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:proportion of ground truth: 0.02572974987769555
# ---evaluation---
#
# proportion of ground truth: 0.02572974987769555
# ---evaluation---proportion of ground truth: 0.02572974987769555
# ---evaluation---
#
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.11172428592276813
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.339984829311085
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10101660753213774
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1660779386596144
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10108922374694752
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10101009510106707
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10580911381650453
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.16607563136606215
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.3620037776850545
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.16607563136606215
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.16607563136606215
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (10.0, 0.0, 10.0)
# AUPRC:  0.3620037776850545
# --- tuning end ---
# target size: 115
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.4030175780433751
# -----
# AUC-ROC all: 0.8781405804014013
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Fold: 1
# Inner Fold: 0
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  [327  39 166 367  17 387 158  45 293  27]target size: 115
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# First few target index:
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 ends:
# KR2 ends:
# proportion of ground truth:proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 ends:
#  0.02529954883247785
# ---evaluation---
# KR2 starts:
# KR2 starts:
# KR2 ends:proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 starts:
#
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 ends:proportion of ground truth: 0.02529954883247785
# ---evaluation---
#
# -----
# AUC-PR all: 0.3708605299795566
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----KR2 ends:
# AUC-PR all: 0.19942405716050157
# -----
# ------ lmd1:  0.01-----
# AUC-PR all: 0.33571740172539444
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.16251103737454908
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
#
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 ends:proportion of ground truth: 0.02529954883247785
# ---evaluation---
#
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.39638914877388776
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3593803030887659
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.19942405716050157
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.19899472809405236
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.332640421194679
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----proportion of ground truth:
# AUC-PR all: 0.40692108795440385
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#  0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.1689429854965735
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.17140290693614776
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.16500811299664533KR2 ends:
# -----
#
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.19921335163783535
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# -----
# AUC-PR all: 0.19899472809405236
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.19899472809405236
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.16228769280351318
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.16221371367373077
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.40692108795440385
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  115
# First few target index:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
# KR2 starts:
# KR2 starts:
#
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.026847961980788496
# ---evaluation---
#  0.026847961980788496
# ---evaluation---
# KR2 ends:
# KR2 ends:KR2 ends:
#
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# -----
# AUC-PR all: 0.19116510560319988-----
# AUC-PR all: 0.3775644979690932
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.19479984468865036
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
#
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: proportion of ground truth: 0.026847961980788496
# ---evaluation---
# 0.026847961980788496
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR2 ends:
#  0.026847961980788496
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.19142389291736533
# -----
# ------ lmd1:  0.1 KR2 ends:proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.24240498532863275lmd1:  0.0 sigma:  1.0 ------
#
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:
# proportion of ground truth: 0.1 ------
# KR2 ends:KR2 ends:
#  0.026847961980788496
# ---evaluation---
#
# -----
# AUC-PR all: 0.34892422654417954
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.24242186269189087
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.24242186269189087
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.19250376381869175
# ----------
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.19108393257349038
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.40558410561430425
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.38881009289949886
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.24073841356565454
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.24073841356565454
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.35355354692724583
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.24073841356565454
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.19108330384607944
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.33052225359941767
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.40558410561430425
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# target size:First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:KR2 starts:
# KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 ends:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:
#
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR2 ends:
# proportion of ground truth:proportion of ground truth:proportion of ground truth: 0.028399481273829952
# ---evaluation---
#  0.028399481273829952
# ---evaluation---
#  0.028399481273829952
# ---evaluation---
# proportion of ground truth:KR2 ends:
#  0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# proportion of ground truth:---evaluation---
# -----
# AUC-PR all: 0.26211837907636876
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
#  0.028399481273829952
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR2 ends:
# KR2 ends:KR2 ends:
#
# KR2 ends:
# -----
# proportion of ground truth: 0.028399481273829952
# proportion of ground truth: -----
# AUC-PR all: 0.21458885050268509
# -----
# ------ lmd1:  1.0 ----------
# AUC-PR all: 0.26211837907636876
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# AUC-PR all:0.028399481273829952lmd1:  0.3948729729476983
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.26211837907636876
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# ---evaluation---
# ---evaluation---
#
# -----
# AUC-PR all: 0.2130444084609685
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.21151037564145658
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.2126811857015148
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.3773415589606282
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# ----------
# AUC-PR all: 0.26211837907636876
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1
# AUC-PR all: 0.21331603420246212
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
#  ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# --------evaluation---KR2 ends:
#
#
# AUC-PR all: 0.361709563579931
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.21264242775047645
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.26211837907636876
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3542353767056141
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.26211837907636876
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4205491929272121
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.4053644323676979
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4205491929272121
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 starts:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR2 ends:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# KR2 starts:
# proportion of ground truth:proportion of ground truth: proportion of ground truth: 0.02280531461363442
# ---evaluation---
#  0.02280531461363442
# ---evaluation---
# 0.02280531461363442
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR2 ends:
# ----------
# AUC-PR all: 0.17267579903129002
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# KR2 starts:
# KR2 ends:
#
# AUC-PR all: 0.17267579903129002
# -----
# ------ lmd1:  0.01 lmd1:  -----
# AUC-PR all: 0.11407692722486774
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------0.0 sigma:  0.1 ------
#
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth:proportion of ground truth: 0.02280531461363442
# ---evaluation---
#  0.02280531461363442
# ---evaluation---
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth:proportion of ground truth:  0.02280531461363442
# ---evaluation---
# 0.02280531461363442
# ---evaluation---
# -----proportion of ground truth: 0.02280531461363442
# ---evaluation---
#
# AUC-PR all: 0.11230193640287381
# -----
# ------ lmd1:  1000.0KR2 ends:
# -----
# AUC-PR all: 0.11230236721453363
# -----
# ------ lmd1:  100.0 proportion of ground truth: 0.02280531461363442
# ---evaluation---
#  lmd1:  0.0 sigma:  1.0 ------
# lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR2 ends:KR2 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
#
# -----
# AUC-PR all: 0.33765480965050587
# -----
# ------ lmd1:  0.1-----
# AUC-PR all: 0.17264127551057287
# -----
# ------ lmd1:  lmd1:  KR2 ends:
#  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.11344917936796513
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# 1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:---------- 0.02280531461363442
# ---evaluation---
#
# AUC-PR all:
# AUC-PR all: 0.17264127551057287
# -----
# ------ lmd1: proportion of ground truth: 0.02280531461363442
# ---evaluation---
#  0.30262056689760874
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#  proportion of ground truth:100.0 lmd1:  0.0 sigma:  0.1 ------
#  0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.1726772862943638
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.11234859458536957
# ----------
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.3617497493484911
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3562800441773528
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.17264127551057287
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.33211113015838123
# -----
# ...
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.3149550037186756
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----proportion of ground truth:KR2 ends:
#  0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
#
# AUC-PR all: 0.3388495162513766
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.3381321870795789
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.14177888209789963
# -----
# ------ lmd1:  0.1 lmd1: KR2 ends:
#  -----0.0
# AUC-PR all: 0.21185453438745241
# -----
# ------ lmd1: proportion of ground truth: 0.01 lmd1:  0.0 sigma:  0.1 ------
#  sigma:  1.0 ------
#  0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.13942658218123904
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.21171160824710603
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.369362571160277
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1346124241157602
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3680873910473397
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.21171160824710603
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.1346240964768392
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.2117742364342038
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.21185453438745241
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.21171160824710603
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (10.0, 0.0, 10.0)
# AUPRC:  0.369362571160277
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index:  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR2 starts:
# KR2 starts:
# KR2 ends:KR2 ends:
# KR2 ends:
# KR2 ends:
#
# KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.02225242085154958
# ---evaluation---
#  -----0.02225242085154958
# ---evaluation---
# KR2 starts:
#
# AUC-PR all: 0.20790350770161806
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR2 ends:
# KR2 ends:
# -----proportion of ground truth: 0.02225242085154958
# ---evaluation---
#
# AUC-PR all:----- 0.20790350770161806
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma: KR2 ends:
#
# AUC-PR all: 0.20790350770161806
# -----
# ------ lmd1:   0.1 ------
# proportion of ground truth:KR2 ends: 0.02225242085154958
# ---evaluation---
# 1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3757484227402821
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#
# KR2 ends:
# KR2 ends:
# -----
# AUC-PR all: 0.31922010139485646
# -----
# ------ lmd1:  0.01 lmd1:  0.0 proportion of ground truth:sigma:  10.0 ------
#  0.02225242085154958
# ---evaluation---
# -----KR2 ends:
# AUC-PR all: 0.14515557052002795
# -----
# ------ lmd1:  0.1 lmd1:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.20790350770161806
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR2 ends:
# proportion of ground truth: KR2 ends:
# proportion of ground truth:0.02225242085154958
# ---evaluation---
#  0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.20790350770161806
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.33830742086754223
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:-----
# AUC-PR all: 0.3535450081547124
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#  0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.14225824676607232
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.20790350770161806
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# -----
# AUC-PR all: 0.14244539666607148
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.14412224183109776
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.14220283065612702
# ----------
# ------ lmd1:
# AUC-PR all: 0.36699774268291296 100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:
# 0.02225242085154958
# ---evaluation---
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1461470894860054
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3154218298679772
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.3757484227402821
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# First few target index:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index:  [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# [309 216 444 217 248 437 178  23 187   8]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:KR2 starts:
#
# KR2 starts:
# KR2 ends:
# KR2 ends:
# proportion of ground truth:KR2 ends: 0.02655909052082282
# ---evaluation---
#
# proportion of ground truth: 0.02655909052082282
# ---evaluation---proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR2 ends:
# KR2 ends:proportion of ground truth:
#  0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.29862093609829815
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# proportion of ground truth:KR2 ends:KR2 ends:
#  0.02655909052082282
# ---evaluation---
# KR2 ends:
# proportion of ground truth:
# -----
# AUC-PR all:  0.02655909052082282
# ---evaluation---
# 0.3700682798865985
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.37038598552909563
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.13580443865327652
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR2 ends:
# proportion of ground truth:proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR2 ends:
#  0.02655909052082282
# ---evaluation---
# KR2 ends:
# KR2 ends:
# -----
# AUC-PR all: 0.1339637492833079
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.13213003488934216
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR2 ends:
# KR2 ends:
# KR2 ends:
# -----
# AUC-PR all:proportion of ground truth: 0.17536227048337907
# -----
#  ------ lmd1:  0.1 lmd1:  0.02655909052082282
# ---evaluation---
# 0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.1751947135278603
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.38602602417873644
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.33231706737528194
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.13229425144577128
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.17536227048337907
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.17492715056484656
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.17492715056484656
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.17492715056484656
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3498805614228788
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1365463828781796
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.13214064021533678
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (10.0, 0.0, 10.0)
# AUPRC:  0.38602602417873644
# --- tuning end ---
# target size: 115
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.39683109346583284
# -----
# AUC-ROC all: 0.9047133509226549
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Mean AUC_pr_all_mean: 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_mean 0.0   Standard Deviation: 0.0
# Mean Fmax_mean 0.0   Standard Deviation: 0.0
# Mean Smin_mean 0.0   Standard Deviation: 0.0
# Mean F1_mean 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all 0.39572050247984963   Standard Deviation: 0.01035114135099569
# Mean AUC_roc_all 0.8898061995728785   Standard Deviation: 0.013354360113622912
# Mean AUC_pr_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn 0.0   Standard Deviation: 0.0
# Mean Fmax 0.0   Standard Deviation: 0.0
# Mean Smin 0.0   Standard Deviation: 0.0
# Mean F1 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_rd 0.0   Standard Deviation: 0.0
# Mean Fmax_rd 0.0   Standard Deviation: 0.0
# Mean Smin_rd 0.0   Standard Deviation: 0.0
# Mean F1_rd 0.0   Standard Deviation: 0.0

# %% [markdown]
# Running the nested CV for integrated features, with multiple kernels

# %%
results_MKR = main(method_option="MKR",Validation="nested_cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# Inner Fold: 0
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115target size: 115target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
#
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index:target size: 115 target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index:
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:[327  39 166 367  17 387 158  45 293  27]
# [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# 115target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index:target size: 115
#  [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# First few target index:115target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:
#
# MKR starts:MKR starts:
#
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:
# MKR starts:
#
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:MKR starts:
#
# MKR starts:
# MKR starts:
#
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02418288980175031MKR starts:
#
# ---evaluation---
# MKR starts:
# MKR starts:MKR starts:
#
# MKR starts:
# MKR starts:
# MKR ends:
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:
# MKR starts:MKR ends:
# MKR starts:
#
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR starts:
# proportion of ground truth:-----
# AUC-PR all: 0.10697724194382238
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR ends:
# MKR ends:MKR ends:
#
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR starts:
# proportion of ground truth:proportion of ground truth:-----
# AUC-PR all: 0.09335269668483512
# -----
# ------ lmd1:  1.0 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR starts: 0.02418288980175031
# ---evaluation---
#
#  0.02418288980175031
# ---evaluation---
# proportion of ground truth:MKR ends:
#  0.02418288980175031
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:MKR starts:
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.3687911665104722
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  MKR ends:
# 10.0proportion of ground truth: 0.02418288980175031
# ---evaluation---
#  0.02418288980175031
# ---evaluation---
# MKR ends:
#  ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.3823791050643268
# -----
# ------ lmd1: proportion of ground truth:MKR ends:
# MKR ends:
#  0.01 lmd1:  1000.0 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# ----- 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR ends:
# AUC-PR all: 0.07575469365932981
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  0.1 ------
# target size: 115
#
# -----
# AUC-PR all: 0.06972623162900934
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# ----------
# AUC-PR all:-----
# AUC-PR all: 0.3646303743614932
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  10.0 ------
# target size:
# AUC-PR all: 0.06936982763879695
# -----
# ------ lmd1:  1.0 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# 115
# First few target index:MKR ends:
# proportion of ground truth: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  0.02418288980175031MKR ends:
#  0.06839869369149754
# -----
# ------ lmd1:  1.0 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.33635744678790636
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.10642924347824151
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  1.0 ------
# MKR ends:
# MKR ends:
# target size: 115
# First few target index: MKR ends:
# -----
# AUC-PR all: 0.07528610962937322
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# -----MKR ends:MKR ends:
#
# MKR ends:
#
# AUC-PR all: 0.10751206304160339
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# -----
# AUC-PR all: 0.07137714090536725
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  0.1 ------
# target size: 115proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.07223063898423598
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  0.1
#  proportion of ground truth:-----
# AUC-PR all: 0.41169660324716995
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  0.02418288980175031
# ---evaluation---
# proportion of ground truth:MKR ends:
#  0.02418288980175031
# ---evaluation---
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# proportion of ground truth:MKR ends:
#  0.02418288980175031
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----MKR ends:proportion of ground truth:
# AUC-PR all: 0.10704109363886025
# -----
# ------ lmd1:  0.01 lmd1:  1000.0 sigma:  1.0 -----proportion of ground truth:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# MKR ends: -----------
#
# AUC-PR all: 0.06971384268314769
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:0.02418288980175031
# ---evaluation---
#
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# AUC-PR all: 0.10289687478497916
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27] 0.02418288980175031
# ---evaluation---
#
# proportion of ground truth: proportion of ground truth: 0.02418288980175031
# ---evaluation---
# 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:MKR ends: 0.02418288980175031
# ---evaluation---
#
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.10339554165034247
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:proportion of ground truth: 0.02418288980175031-----
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# MKR ends:
# ----------MKR starts:
#
#
# AUC-PR all: 0.07584527584969707
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# AUC-PR all: 0.4101404332150391
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma: -----
# AUC-PR all: 0.40501856141745085
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  10.0 ------
# target size:  10.0 ------
# MKR ends:
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# 115First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.07140275935033817
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  0.1 ------
# target size:proportion of ground truth:AUC-PR all:  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  0.4063823802873638
# -----
# ------ lmd1:  1.0 lmd1:  1.0 sigma: 0.02418288980175031
# ---evaluation---
#  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.335619812664499
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# -----
# AUC-PR all: 0.07570559283380868
# -----
# ------ lmd1:  0.1 lmd1:  100.0 sigma:  0.1 ------
# target size: 115
# MKR ends:
# First few target index:proportion of ground truth: First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# 0.02418288980175031 [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.4065184627318985
# -----
# ------ lmd1:  0.1 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# proportion of ground truth:
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation--- 0.02418288980175031
# ---evaluation---
#
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# ----------
# AUC-PR all: 0.07529131136361311
#
# -----
# ------ lmd1:  0.01 lmd1:  100.0 sigma:  0.1 ------
# target size:AUC-PR all: 0.09580104990610074
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.0753287542493373
# -----
# ------ lmd1:  0.01 lmd1: proportion of ground truth: 1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#   0.02418288980175031
# ---evaluation---
# 0.02418288980175031
# proportion of ground truth: 0.02418288980175031---evaluation---
#
# ---evaluation---
# proportion of ground truth:-----
#  AUC-PR all:0.02418288980175031
# -----
# AUC-PR all: 0.38843497152873513
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  10.0---evaluation---  ------
# 0.3845257437373405
# -----
# ------ lmd1:  0.01
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# proportion of ground truth: 0.02418288980175031
# lmd1: ---evaluation--- -----
# AUC-PR all: -----0.09983278910296926
# proportion of ground truth:
#  0.02418288980175031-----
# ------ lmd1:  1.0 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# AUC-PR all: 0.10591012305965652
# -----
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# ---evaluation---
# -----
# AUC-PR all: 0.07578267318858276
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.10722129067229573
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.38758248497583325
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  10.0 ------
# target size:----- 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# AUC-PR all: 0.10600999381580214
# -----
# ------ lmd1:  0.1 lmd1:  100.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.10711149585519347
# -----
# ------ lmd1:  0.01 lmd1:  100.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.09940805864241371
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.07572167611390868
# -----
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.33205223930548494
# ----------
# -----
#
# AUC-PR all: 0.07535931008388855
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# AUC-PR all:------ lmd1:  1.0 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  0.10003705532197288
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.10727413030901464
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.07182545228676707
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.40442105638807035
# -----
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# -----
# AUC-PR all: 0.3732380327229533
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  10.0 ------
# target size: -----
# 115
# First few target index:AUC-PR all: 0.09555437324962154
# [327  39 166 367  17 387 158  45 293  27]-----
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.09333594624104714
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.3624380625831564
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.07135955525446568
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR starts:MKR ends:
#
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.06952792505505248
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.09162606532084606
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.06930141573660932
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.02418288980175031proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
#
# -----
# AUC-PR all: 0.09906246979337789
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: MKR starts:
# [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---MKR ends:
# MKR starts:
#
# -----
# AUC-PR all: 0.4027171911787557
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR starts:
# MKR ends:
# proportion of ground truth:MKR starts:
#  0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.3546989780840092
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  10.0 ------
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# proportion of ground truth:MKR starts:-----
# AUC-PR all: 0.06688019113798577
# -----
# ------ lmd1:  10.0 lmd1:  0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.0694128502298085
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  0.1 ------
#
# MKR starts:-----
# AUC-PR all: 0.3708361259728095
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  10.0 ------
# MKR starts:
# MKR ends: 1000.0 sigma:  0.1 ------
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.06671257804465766
# -----
# ------ lmd1:  100.0 lmd1:
#
# 1000.0 sigma:  0.1 ------
# MKR ends:
# proportion of ground truth:MKR starts:
# MKR ends: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.085443864755693
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  1.0 ------
#
# MKR starts:
#  0.02418288980175031
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:
# MKR starts:
# -----proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# MKR ends:proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:
#  0.02418288980175031
# ---evaluation---
# AUC-PR all: 0.0695244738401298
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  0.1 ------
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR starts:
# proportion of ground truth:proportion of ground truth:MKR ends:
#  MKR ends:
# 0.02418288980175031
# ---evaluation---
# MKR ends:
# proportion of ground truth:proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
#  0.02418288980175031
# ---evaluation---
#  0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031proportion of ground truth:
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends: -----
# AUC-PR all: 0.06689772026531123
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06934748604820604
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09330292255638178
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  1.0 ------
# 0.02418288980175031
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR ends:-----
# AUC-PR all: 0.3297469145113178
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  10.0 ------
#
#
# MKR starts:
# -----
# AUC-PR all: 0.0923233537769757
# -----
# -----
# AUC-PR all: 0.3981768886595608
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  10.0 ------
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  1.0 ------
# MKR ends:
# -----
# AUC-PR all: 0.06933188468301776
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06953272223019724
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  0.1 ------
# -----
# AUC-PR all: 0.32131410954391204
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031
# MKR ends:
# ---evaluation---
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth:
# MKR ends:proportion of ground truth:
# MKR ends:0.02418288980175031 0.02418288980175031
# ---evaluation---
#
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.3954263225927735
# -----
# ------ lmd1:  10.0 lmd1: -----MKR ends:
# -----
# AUC-PR all: 0.3276643194735333
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  10.0 ------
#
#  proportion of ground truth: 0.02418288980175031
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# ---evaluation---
# AUC-PR all:1.0 sigma:  10.0 ------
#  0.08855624585928781
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  1.0 ------
#
# proportion of ground truth:MKR starts:
#  0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.06714942424389128
# -----
# ------ lmd1: proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
#  MKR ends:MKR ends:
# -----
# AUC-PR all: 0.09159879195732172
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  1.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# 10.0 lmd1:  10.0 sigma:  0.1 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR ends:
# MKR starts:
# -----
# AUC-PR all: 0.08953988631438956
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  MKR ends:1.0MKR ends:
#  ------
#
# MKR starts:
# MKR ends:proportion of ground truth:proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.09329738582241948
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:
#  1.0 ------
#  proportion of ground truth: 0.02418288980175031
# MKR ends:
# -----
# AUC-PR all: 0.0880740614074634
# -----
# ------ lmd1:  10.0 0.02418288980175031
# ---evaluation---
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# lmd1:  1000.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.06912711608583386
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.35979968745739255
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09223947987559072-----
# AUC-PR all: 0.09068299910861087
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  1.0
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  1.0-----
# AUC-PR all: 0.36007673926691774
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma: -----
# AUC-PR all: 0.09065190016646132
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  1.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
#  ------
#  10.0 ------
# proportion of ground truth: 0.02418288980175031
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# ---evaluation---MKR ends:
#
#  -----
# AUC-PR all: 0.06695488151890898
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  0.1 ------
# MKR ends:
# ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.06932934351209508
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  0.1 ------
# MKR ends:-----
# AUC-PR all: 0.09377452372665283
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  1.0 ------
#
# MKR ends:proportion of ground truth:----------
# AUC-PR all: 0.380222507257277
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  10.0 ------
#
#
# AUC-PR all: 0.09732883860321881
#  0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.08856915152258818-----
# AUC-PR all: 0.34692617434588063
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  10.0 ------
#
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  1.0 ------
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  -----
# AUC-PR all: 0.06912503341354753
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  0.1 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# 1.0 ------
# -----
# AUC-PR all: 0.3957959358951759
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# ---evaluation---
# -----
# AUC-PR all: 0.38665865839468
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.06921994716235706
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  0.1 ------
# MKR ends:
# -----
# AUC-PR all: 0.0693484958786777
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  0.1 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.38923851002774273
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  10.0 ------
# MKR ends:
# -----
# AUC-PR all: 0.3802306496039669
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0841545743409564
# -----
# ----------- lmd1:  100.0 lmd1:  1000.0 sigma:
#  AUC-PR all: 0.3824835861879867
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  10.0 ------
# 1.0 ------
# MKR ends:proportion of ground truth: 0.02418288980175031
# ---evaluation---
#
# MKR ends:
# -----
# AUC-PR all: 0.06695301814331057
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  0.1 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.08493557783312942
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3416908166836946
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.35589785368582666
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 10.0, 10.0)
# AUPRC:  0.41169660324716995
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: target size: 115
# [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
#   target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index:First few mask index:
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  [397 369  92 268 306 322 110 284 140 210]target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: target size: 115
# 115
# First few target index: target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
#  115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# First few target index: [397 369  92 268 306 322 110 284 140 210]target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index:
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# First few target index: target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# MKR starts:
# MKR starts:MKR starts:
#
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
#
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:MKR ends:
#
# MKR starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR ends:
# proportion of ground truth:MKR starts:
# MKR ends: 0.024706275188892426
# ---evaluation---
#
# MKR ends:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR starts:
# MKR ends:MKR starts:MKR ends:
# MKR starts:
# proportion of ground truth:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
#
#  0.024706275188892426
# ---evaluation---
# MKR ends:
# MKR starts:-----
# AUC-PR all: 0.06424108838391937
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]MKR ends:
# MKR ends:
#
#
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth:MKR ends:MKR ends:
# -----
# AUC-PR all: 0.07935397211898987
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  1.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# 0.024706275188892426
# ---evaluation---
# MKR ends:MKR ends:
#
# MKR ends:
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.36244632352549055
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# -----
# AUC-PR all: 0.08875145084051596
# -----
# ------ lmd1:  1.0 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# MKR ends:-----
# AUC-PR all: 0.08489687918782729
# -----
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# proportion of ground truth: proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# 0.024706275188892426
# ---evaluation---
# MKR ends:
# MKR ends:
#
# MKR ends:
# MKR ends:
# proportion of ground truth:MKR ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
#  0.024706275188892426
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.08652204209448462
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.06338194655810361
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR ends:MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.38977148559245933
# -----
# ------ lmd1:  0.01 lmd1:  100.0MKR ends:
#
#  sigma:  10.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# proportion of ground truth:proportion of ground truth: 0.024706275188892426
# ---evaluation---
#  0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.0871174125617335
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  1.0 ------MKR ends:
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# MKR ends:
#
# -----
# AUC-PR all: 0.08567508886016473
# -----
# ------ lmd1: MKR ends:
# 0.1 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# MKR ends:
# proportion of ground truth: -----
# ...
# -----
# AUC-PR all: 0.07240584604600536
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# -----
# AUC-PR all: 0.10326510022990236
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# -----MKR ends:
#
# AUC-PR all: 0.09894812185797036
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# ----------
# AUC-PR all: 0.07597310738748232
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
#
# AUC-PR all: 0.37005590208908534
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  10.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# MKR starts:
# MKR starts:
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# -----
# AUC-PR all: 0.10219980005699014
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# -----
# AUC-PR all: 0.07513056102209967
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma: MKR ends:MKR starts:
#
#  First few target index:-----0.1
# AUC-PR all: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# -----
# AUC-PR all: 0.36431190178433304
# -----
# ------ lmd1:  0.01 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  proportion of ground truth: 0.02655909052082282
# ---evaluation---
#  ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# 0.10370410277766048
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  1.0 MKR ends:
# proportion of ground truth: ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# 0.02655909052082282MKR starts:
# -----
# AUC-PR all: 0.07493640071358407
# -----
# ---evaluation---
#
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# MKR ends:proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR starts:
# MKR ends:
# MKR ends:
# MKR starts:
# -----MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# AUC-PR all: 0.07567827797667094
# -----
# ------ lmd1:  MKR ends:-----
# AUC-PR all: 0.10150769192618242
# -----
# ------ lmd1:  10.0
# 0.1 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  MKR ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# proportion of ground truth:-----MKR ends:lmd1:
#
#  -----
# AUC-PR all: AUC-PR all:0.41568426307422324 1.0 sigma:  1.0 ------
# target size: 115
# First few target index: proportion of ground truth:[309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# 0.02655909052082282
# ---evaluation---
#  0.09941251626077482
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  0.02655909052082282
# ---evaluation---
#  MKR starts:
# 1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR ends:
# MKR starts:
# -----
# AUC-PR all: 0.38909138942869603
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  10.0 ------
# target size: -----
# AUC-PR all: 0.09602516601725986
# -----
# MKR ends:------ lmd1:  10.0 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# proportion of ground truth:proportion of ground truth:proportion of ground truth: 0.02655909052082282 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.07495599997619129
# -----
# ------ lmd1:  10.0 lmd1:
# ---evaluation---
# 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  0.02655909052082282
# ---evaluation---
# -----0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]MKR ends:-----
# AUC-PR all: 0.3994644954275297
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
#
# AUC-PR all:MKR ends:
# -----
# AUC-PR all:-----
# AUC-PR all: 0.10217314767175803
# -----
# ------ lmd1:
#  10.0 lmd1:  0.1 sigma:  1.0 ------
# 0.413974971259846
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  10.0 ------
# MKR starts:
# proportion of ground truth: 0.02655909052082282
#  0.10536827503871372
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  1.0 ------
# MKR ends:MKR ends:
#
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# MKR ends:MKR ends:
#
# MKR starts:
# -----
# AUC-PR all: 0.07068427283281659
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3066574674123492
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# -----
# AUC-PR all: 0.3048892128901077
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  10.0 ------
# proportion of ground truth:MKR ends:
# MKR starts:
#  0.02655909052082282
# ---evaluation---
# MKR ends:MKR ends:
#
# MKR ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.10264098002996445
# -----
# proportion of ground truth: 0.02655909052082282
# ---evaluation---MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# ------ lmd1:  100.0 lmd1:  0.01 sigma: proportion of ground truth: 1.0 ------
#
#  0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.39535066222274057
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09267387780819566
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  1.0 ------
# MKR starts:MKR ends:
#
# MKR starts:
# MKR starts:
# -----
# AUC-PR all: 0.10079297708451924
# -----MKR ends:
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
#
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  1.0 ------
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.07491255292244982
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  0.1 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.07319420847189353
# -----
# ------ lmd1:  10.0 lmd1:  proportion of ground truth:10.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07069519765488698
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  0.1 ------
# MKR ends:
#  0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# MKR ends:
# -----
# AUC-PR all: 0.10265237255560344
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  1.0 ------
# MKR ends:-----
# AUC-PR all: 0.09354087298279726
# -----
# ------ lmd1:  10.0 lmd1:  100.0proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
#  sigma:  1.0 ------
# MKR starts:
# -----
# AUC-PR all: 0.3417816009481086
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.07441272200737153
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  0.1 ------
# MKR ends:
# MKR ends:
# MKR starts:
# MKR ends:-----
# AUC-PR all: 0.3383651409863073
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  10.0 ------
#
# proportion of ground truth: 0.02655909052082282
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# ---evaluation---
# -----
# AUC-PR all:-----
# AUC-PR all: 0.07467763228145904
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  0.1 ------
#  0.0749194319844999
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  0.1 ------
# MKR starts:
# -----
# AUC-PR all: 0.3737772439631008
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09741560448395614
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR starts:
# MKR ends:MKR starts:
#
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# MKR starts:
# -----
# AUC-PR all: 0.07452328384869186
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  0.1 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:-----
# AUC-PR all: 0.3009386039630627
# -----
# MKR ends:MKR ends:
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  10.0 ------MKR ends:
#
# MKR starts:
#
# -----
# AUC-PR all: 0.07489074759454167
# -----
# ------ lmd1:  100.0 lmd1:  0.01
# -----sigma:
#  0.1 ------
# MKR ends:
# AUC-PR all: 0.07325442061172407
# -----
# ------ lmd1:  100.0 lmd1:  100.0-----
# AUC-PR all: 0.38832534355164905
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  10.0 ------
#  sigma:  0.1 ------
# -----proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# AUC-PR all:proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.0924938205801758
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  1.0 ------
# proportion of ground truth: 0.07072783444402983
# -----
# ------ lmd1:  100.0 lmd1: proportion of ground truth: 0.02655909052082282
# ---evaluation---
#   0.02655909052082282
# ---evaluation---
# 1000.0 proportion of ground truth: 0.02655909052082282
# ---evaluation---
# sigma:  0.1 ------
# MKR ends:
# -----
# AUC-PR all: 0.37924089357526
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  10.0 ------
# proportion of ground truth:proportion of ground truth: 0.02655909052082282
# ---evaluation---
#  0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.3754572790483264
# -----
# ------ lmd1: MKR starts:
#  100.0 lmd1:  MKR ends:1.0 sigma:  10.0 ------
#
# MKR ends:
# -----
# AUC-PR all: -----
# AUC-PR all: 0.10221197175625762
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1025353076787715
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# 0.38654744486871145
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.3361512161160006
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.38305837112713226
# -----
# ------ lmd1: MKR ends:
#  10.0 lmd1:  1.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09090752828108203
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  1.0 ------
# MKR ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.10417688785731789
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.07441470702087763
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3659867300855875
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  10.0 ------
# MKR ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# MKR ends:
# -----
# proportion of ground truth: 0.02655909052082282
# AUC-PR all: 0.3764701476792217
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07450144508487037
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09182576466028776
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07440952865378347
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  0.1 ------
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.3697570298409857
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  10.0 ------
# proportion of ground truth:-----
# AUC-PR all: 0.07491571090239858
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07325305573842447
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  0.1 ------
#  0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.1036715916651313
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  1.0 ------
# MKR ends:
# -----
# AUC-PR all: 0.09619622902811648
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.10196426416507923
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 100.0, 10.0)
# AUPRC:  0.41568426307422324
# --- tuning end ---
# target size: 115
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  10.0 ------
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4529550667057008
# -----
# AUC-ROC all: 0.8949615912684752
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Mean AUC_pr_all_mean: 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_mean 0.0   Standard Deviation: 0.0
# Mean Fmax_mean 0.0   Standard Deviation: 0.0
# Mean Smin_mean 0.0   Standard Deviation: 0.0
# Mean F1_mean 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all 0.4420810771997069   Standard Deviation: 0.0089850763696277
# Mean AUC_roc_all 0.8905319119086968   Standard Deviation: 0.009376544070143192
# Mean AUC_pr_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn 0.0   Standard Deviation: 0.0
# Mean Fmax 0.0   Standard Deviation: 0.0
# Mean Smin 0.0   Standard Deviation: 0.0
# Mean F1 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_rd 0.0   Standard Deviation: 0.0
# Mean Fmax_rd 0.0   Standard Deviation: 0.0
# Mean Smin_rd 0.0   Standard Deviation: 0.0
# Mean F1_rd 0.0   Standard Deviation: 0.0

# %% [markdown]
# Running KR for integrated features. Features are linear combination.

# %%
results_KR1KR2 = main(method_option="KR1&KR2",Validation="nested_cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# Inner Fold: 0
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
# KR1&KR2 ends:
#
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.0739942007187048
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:KR1&KR2 ends:
#
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:proportion of ground truth: 0.02418288980175031
# ---evaluation---
# KR1&KR2 ends:proportion of ground truth: 0.02418288980175031
#
# ---evaluation---
#
# -----
# AUC-PR all: 0.37767203484651385
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.40083161791803124
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0672204689851341
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# ----------
# AUC-PR all: 0.09896498464826606
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.4091293245328403
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0871349935388428
# proportion of ground truth:----- 0.02418288980175031
# ---evaluation---
#
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.08668669080254025
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3373119184913464
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.06722794086334563
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# proportion of ground truth: 0.02418288980175031
# ---evaluation---
# -----
# AUC-PR all: 0.09030469647643694
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10296123943140964
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07275286575603601
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07397537305205328
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.06733113868016816
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.374432297611312
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10266799782278668
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.34738198181020935
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4091293245328403
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 starts:
# KR1&KR2 starts:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1&KR2 ends:
#
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
#
# KR1&KR2 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:-----
# AUC-PR all: 0.07743105341461774
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
#
# proportion of ground truth:KR1&KR2 ends:
#  0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.06210747778296746
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.08585782644798041
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# proportion of ground truth:proportion of ground truth:  0.024706275188892426
# ---evaluation---
# 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.06322102517544062
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.3400556518002958
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# KR1&KR2 ends:
# ----------
# AUC-PR all: 0.4196555703190414
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#
# -----
# AUC-PR all: 0.06208666570364916
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# AUC-PR all: 0.07955226493603654
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07719382105210211
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.331457639984612
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.062059096896458416
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4122981794676016
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# AUC-PR all: 0.3682297743838341
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# -----
# KR1&KR2 ends:
# AUC-PR all: 0.08213379418315184
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.06289727538818714
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.024706275188892426
# ---evaluation---
# ----------
# AUC-PR all: 0.3986694715293743
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#
# AUC-PR all: 0.06328338536964057
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.08505957674748955
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4196555703190414
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# 115
# First few target index: target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth:KR1&KR2 ends: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1&KR2 starts:
#
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.028759794062604347proportion of ground truth: 0.028759794062604347
# ---evaluation---
#
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.15391229001439743proportion of ground truth: 0.028759794062604347
# ---evaluation---
#
# -----
# ------ lmd1:  0.01 proportion of ground truth: 0.028759794062604347
# ---evaluation---
# lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.12025115354031546
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# KR1&KR2 starts:
# -----
# AUC-PR all: 0.1486769847624517
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.13075531534584975
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.3878410605862575
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.12006568328153819
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# ----------
# AUC-PR all: 0.11670541821687701
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.12183893495804975
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:KR1&KR2 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# KR1&KR2 ends:-----
# -----
# AUC-PR all: 0.11672769388216878
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
#
#
# AUC-PR all: 0.11674429579130555
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4477044089996455
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.15385476081831437
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.4443960168760117
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.41634203625966254
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.4227510139375775
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.13642057286704054
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: KR1&KR2 ends:0.3781191408510908
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
#
# proportion of ground truth: 0.028759794062604347
# ---evaluation---
# -----
# AUC-PR all: 0.12992974955777578
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4477044089996455
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index:
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  [309 216 444 217 248 437 178  23 187   8]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 starts:
# proportion of ground truth:KR1&KR2 ends:
# KR1&KR2 ends:
#  0.02572974987769555
# ---evaluation---
# KR1&KR2 starts:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth:proportion of ground truth:proportion of ground truth:  0.02572974987769555
# ---evaluation---
# KR1&KR2 ends: 0.02572974987769555
# ---evaluation---
# KR1&KR2 ends:
#
# KR1&KR2 ends:
# 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.07915372624349223
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth:proportion of ground truth:----- 0.02572974987769555
#
# AUC-PR all: 0.332602585981379
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
#  -----
# AUC-PR all: 0.39703711043228734
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# ---evaluation---0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.37327149903654566
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
#
# -----
# AUC-PR all: 0.08500895000408673
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----KR1&KR2 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
#
# AUC-PR all: 0.3684971610616885
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# KR1&KR2 ends:-----
# AUC-PR all: 0.34162131634705306
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
#
# -----
# AUC-PR all: 0.08153081629801583
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07914292070556625
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.0807449919598063
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# -----
# AUC-PR all:AUC-PR all: 0.08780923711484989
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
#  0.09830123096003994
# -----
# ------ lmd1:  ----------
#
# -----
# AUC-PR all: 0.09401847735197738
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# AUC-PR all:0.01 lmd1:  0.0 sigma:  1.0 ------
#  0.09768917823328369
# -----
# ------ lmd1:  0.1 lmd1: AUC-PR all: 0.08464993785399369
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.4018674839797615
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08152028967290118
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.02572974987769555
# ---evaluation---
# -----
# AUC-PR all: 0.07913679806928595
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4018674839797615
# --- tuning end ---
# target size: 115
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.4330918003215146
# -----
# AUC-ROC all: 0.8983226734262431
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Fold: 1
# Inner Fold: 0
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# target size:target size: 115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
#  115
# First few target index: [327  39 166 367  17 387 158  45 293  27]
# First few mask index: [327  39 166 367  17 387 158  45 293  27]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 starts:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785KR1&KR2 ends:KR1&KR2 starts:
#
#
# ---evaluation---
# KR1&KR2 starts:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:
#
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:-----
# AUC-PR all: 0.07541073751248704
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#  0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.4311480138359275
# -----
# ------ lmd1:  0.1
# lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.09059832417344837
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma: KR1&KR2 ends: 1.0 ------
#
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: -----
# AUC-PR all: 0.07295058059979398
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# 0.08731353394611421
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:-----
# AUC-PR all: 0.4339956160185449
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#  0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.09975612660764047
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# ----------
# AUC-PR all: 0.4012419107417898
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#
# AUC-PR all: 0.35489229802872196
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.38975215362444626
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07418110273332121
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10010467320607035
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# ----------
# AUC-PR all: 0.07295676694693744
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.07294396444777167
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09697188222728002
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.34428582692678456
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02529954883247785
# ---evaluation---
# -----
# AUC-PR all: 0.0876495019102699
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07533332946574921
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4339956160185449
# Inner Fold: 1
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  target size: 115
# 115First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# target size:target size: 115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
#  115
# First few target index: [397 369  92 268 306 322 110 284 140 210]
# First few mask index: [397 369  92 268 306 322 110 284 140 210]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:proportion of ground truth: 0.026847961980788496
# ---evaluation---
#
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1&KR2 ends:proportion of ground truth:
#  0.026847961980788496
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth:
#  0.026847961980788496
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
#
# KR1&KR2 ends:
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.07626739199080279
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:KR1&KR2 ends: proportion of ground truth: 0.026847961980788496
# ---evaluation---
# 0.026847961980788496
# proportion of ground truth:
# ---evaluation---
# proportion of ground truth:  0.0268479619807884960.026847961980788496
# ---evaluation---
# proportion of ground truth:
# ---evaluation---
#  0.026847961980788496
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:proportion of ground truth: 0.026847961980788496
# ---evaluation---
#
# -----
# AUC-PR all: -----0.4208581333499312
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07943904905004542
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.34770708674861606
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.42346296224200836
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08066022742644172
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# ----------
# AUC-PR all: 0.08054700151241717
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.38230984682269875
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.09206236712536642
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09587238020253876
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07630610098129559
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10512408637411408
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.1138138911374738
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3981033299363602
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0916211083423083
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3560107299970351
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1126021259840651
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.026847961980788496
# ---evaluation---
# -----
# AUC-PR all: 0.07635602415046425
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.42346296224200836
# Inner Fold: 2
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# [409 406 371  86 278 416 265 164 252 213]target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: First few mask index: [409 406 371  86 278 416 265 164 252 213]
#
# [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
#  target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:KR1&KR2 ends:
#
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
#
# KR1&KR2 ends:
# KR1&KR2 starts:
# proportion of ground truth: -----
# AUC-PR all: 0.37476761644375056
# -----
# ------ lmd1: proportion of ground truth: 0.028399481273829952
# ---evaluation---
# 0.028399481273829952 100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:KR1&KR2 ends:
# ---evaluation---
# -----
#  0.028399481273829952
# ---evaluation---
# KR1&KR2 ends:
#
# proportion of ground truth:AUC-PR all: 0.11208320604572575
# -----
# ------ lmd1:  1000.0 lmd1:   0.028399481273829952
# ---evaluation---
# 0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.1092800844555118
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.12922593660286988
# -----
# -----
# AUC-PR all: 0.42232563180497645
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.10886288443097934
# -----
# KR1&KR2 ends:------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
#
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.10766486150460189
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# ----------
# AUC-PR all: 0.10762851780088988
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4435940818191642
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#
# AUC-PR all: 0.13437301900085322
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# KR1&KR2 ends:proportion of ground truth: 0.028399481273829952
# ---evaluation---
# ----------
# AUC-PR all: 0.36549378607680894
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
#
#
# AUC-PR all: 0.13489671450444968
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.11273622272941095
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:proportion of ground truth: 0.028399481273829952
# ---evaluation---
#  0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.10763310186300085
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.11780841660932151
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.40341776122689843
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.4458619115573807
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.028399481273829952
# ---evaluation---
# -----
# AUC-PR all: 0.10892966562049367
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4458619115573807
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 starts:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.02280531461363442
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1&KR2 starts:
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.11363864343387893
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:proportion of ground truth: 0.02280531461363442proportion of ground truth: 0.02280531461363442
# ---evaluation---
#
# ---evaluation---
# proportion of ground truth:
#  0.02280531461363442
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# -----
# AUC-PR all: 0.09925668566432398
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:----------
# AUC-PR all: 0.3652550639987499
# -----
# ------ lmd1:  0.02280531461363442-----
# AUC-PR all:
# ---evaluation---
# -----
# AUC-PR all: 0.08372404287327381
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
#  0.08263832490303138
# -----
# AUC-PR all:
# proportion of ground truth:------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# 0.10840963155777747
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
#  0.02280531461363442
# ---evaluation---
# proportion of ground truth: 0.02280531461363442
# ---evaluation---
# KR1&KR2 ends:
#  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# ...
# proportion of ground truth: 0.026566855882649853
# ---evaluation--------
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
#
# -----
# KR1&KR2 ends:AUC-PR all:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends: 0.07747069766837907
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
#
# KR1&KR2 ends:
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.3980061485946935
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.365801135428476
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10911612272931752
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09234066929125463
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:proportion of ground truth: 0.026566855882649853
# ---evaluation---
#
# KR1&KR2 ends:
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.07746135360484391
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026566855882649853
# ---evaluation---
# -----
# AUC-PR all: 0.07750473017343684
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.34158021731001226
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3338740501628561
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0877020974433919
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08822279484924878
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10864200751615649
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.3980061485946935
# Inner Fold: 2
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# target size:target size: 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
#  115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# 115
# First few target index: [409 406 371  86 278 416 265 164 252 213]
# First few mask index: [409 406 371  86 278 416 265 164 252 213]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth:proportion of ground truth: 0.02225242085154958
# ---evaluation---
#  0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:proportion of ground truth:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# 0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.3621261735500637
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:-----
# AUC-PR all: 0.07817897238657871
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
#  KR1&KR2 ends:
# 0.02225242085154958
# ---evaluation---
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.33652818081465996
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------KR1&KR2 ends:
#
# -----
# AUC-PR all: 0.11163008111643818
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3933079296876917
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
#  0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: -----
# AUC-PR all: 0.08297230944230136
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.39887443229267516
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:-----
# AUC-PR all: 0.07834868479638851
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
#
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.3684917494693732
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08224039167887012
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.07816599595239476
# -----
# ------ lmd1: -----
# AUC-PR all: 0.10510172683233039
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
#  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.3440588699695537
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
#  0.02225242085154958
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.09463438713542491
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08292876040830553
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02225242085154958
# ---evaluation---
# -----
# AUC-PR all: 0.11127983100817121
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09032295335067358
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.0897706220911478
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.39887443229267516
# Inner Fold: 3
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size:target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# target size: 115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
#  115
# First few target index: [309 216 444 217 248 437 178  23 187   8]
# First few mask index: [309 216 444 217 248 437 178  23 187   8]
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1&KR2 ends:proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
#
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----proportion of ground truth:
# AUC-PR all: 0.07393449978504602
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.36251295525000843
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
#  0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.10575501277153421
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09624616212323386
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.07633609697914115
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10196061478751153
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09360145599158974
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.40326035494868584
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# proportion of ground truth:KR1&KR2 ends:
# -----
# -----
# AUC-PR all: 0.07679917202887773
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# AUC-PR all: 0.0739159893800733
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
#  0.02655909052082282
# ---evaluation---
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.09390261742713561
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.07399661461562138
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3600471498446069
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---proportion of ground truth: 0.02655909052082282
# ---evaluation---
#
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.07683285042764758
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02655909052082282
# ---evaluation---
# -----
# AUC-PR all: 0.3891928476822914
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.36992077359406456
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.39207844410066717
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10659011612583631
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.40326035494868584
# --- tuning end ---
# target size: 115
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4431965526331105
# -----
# AUC-ROC all: 0.9074787993622864
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
# Mean AUC_pr_all_mean: 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_mean 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_mean 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_mean 0.0   Standard Deviation: 0.0
# Mean Fmax_mean 0.0   Standard Deviation: 0.0
# Mean Smin_mean 0.0   Standard Deviation: 0.0
# Mean F1_mean 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all 0.4314651075879903   Standard Deviation: 0.011065688397145798
# Mean AUC_roc_all 0.895403192550295   Standard Deviation: 0.014649549938223561
# Mean AUC_pr_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn 0.0   Standard Deviation: 0.0
# Mean Fmax 0.0   Standard Deviation: 0.0
# Mean Smin 0.0   Standard Deviation: 0.0
# Mean F1 0.0   Standard Deviation: 0.0
# -----------
# Mean AUC_pr_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_all_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_per_drug_rd 0.0   Standard Deviation: 0.0
# Mean AUC_pr_topn_rd 0.0   Standard Deviation: 0.0
# Mean AUC_roc_topn_rd 0.0   Standard Deviation: 0.0
# Mean Fmax_rd 0.0   Standard Deviation: 0.0
# Mean Smin_rd 0.0   Standard Deviation: 0.0
# Mean F1_rd 0.0   Standard Deviation: 0.0

# %% [markdown]
# ### 2.2. CV to tune hyperparameters for independent test set

# %% [markdown]
# Running CV for DGI. The best hyperparameters are $\lambda=0.1, \sigma=10$.

# %%
main(method_option="KR1",Validation="cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
# KR1 starts:
# KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:KR1 starts:
# KR1 starts:
#
# KR1 starts:KR1 ends:
#
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1 starts:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  0.025335269496882206
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.06859326607310037
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.3657129874496396
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.06921584888478743
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.11896996809628428
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10228137349023947
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# KR1 ends:-----
# AUC-PR all: 0.06855067308005494
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
#
# -----
# AUC-PR all: 0.12140524373328035
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3873031733146037
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.4233123575074856
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3941959764025751
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.07804474261783051
# -----
# ------ lmd1:  KR1 ends:
# 0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.07610185366195785
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09255215907726526
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.09392695377918574
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.35769741417772927
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.4180512365992356
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1190694030985335
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.07832147738052461
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4233123575074856
# Fold: 1
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# 115
# First few target index: target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
#
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
# KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# proportion of ground truth:KR1 ends:
# KR1 starts:KR1 ends:
#  0.025361671727094123
# ---evaluation---
# KR1 starts:
# KR1 starts:
# KR1 starts:
#
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1 ends:
# KR1 starts:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1 ends:KR1 ends:
#
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.025361671727094123
# proportion of ground truth:---evaluation---
#  -----
# AUC-PR all: 0.10692181103181123
# -----
# ------ lmd1:  0.025361671727094123
# ---evaluation---0.01 lmd1:  0.0 KR1 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# sigma:  1.0 ------
#
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.0699941539102667
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#  0.025361671727094123
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.43305940448076646
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3912703100773257
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.10725104799172056
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07863118381615541
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.0604779977606093
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# -----KR1 ends:
#
# AUC-PR all: 0.35733492806237793
# -----
# ------ lmd1:  100.0 lmd1:  0.0-----
#  -----
# AUC-PR all: 0.06696521132920819sigma:  10.0 ------
#
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# AUC-PR all: 0.06958213410799616
# ----------
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.060817058294437926
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.34870570551970703
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.39755131421609474
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.06049296924644129
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.4359901785436125
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.0798172760188705
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08711122096122902
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10218770668665682
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4359901785436125
# Fold: 2
# target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index:target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  [144 278  36  84  99 379 361 173 355 478]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
# KR1 starts:
# KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 starts:
# KR1 starts:proportion of ground truth: 0.02614131405452837
# ---evaluation---
#
# KR1 ends:
# KR1 ends:
# KR1 ends:
# proportion of ground truth:KR1 ends:
#  0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1 ends:KR1 ends:
#
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.0632752713116232
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.06328942022824424
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4338501040726123
# -----
# ------ lmd1: ----- 0.1 lmd1:  0.0 sigma:  10.0 ------
#
# AUC-PR all: 0.38128560314566895
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:proportion of ground truth: 0.02614131405452837
# ---evaluation---
# ----------
# AUC-PR all: 0.07542756653112348
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 -----
# AUC-PR all: 0.08508105214667569
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
#
#
# AUC-PR all: 0.41457172526949326
# ------
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.06854078665061852
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07805414461473555
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.07919543472339721
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09824032587476074
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.11091294440044858
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.07567156319016664
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# -----
# AUC-PR all: 0.3496797466302861
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.06361111435361277
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# KR1 ends:
# -----
# AUC-PR all: 0.42392531827719854
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.341897371646975
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10745235102324133
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4338501040726123
# Fold: 3
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  115
# First few target index: [386 149 145  47  29 286 102  15   2 298] 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index:  115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298][386 149 145  47  29 286 102  15   2 298]
#
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#
# target size: 115
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:First few target index: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 ends:
# proportion of ground truth: KR1 starts:
# 0.025841571088004847
# ---evaluation---
# KR1 ends:
# KR1 ends:proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1 starts:
#
# KR1 ends:
# KR1 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---KR1 ends:KR1 ends:proportion of ground truth:
#
#  0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
#
# proportion of ground truth: proportion of ground truth:0.025841571088004847
# ---evaluation---
#  0.025841571088004847
# ---evaluation---
# KR1 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.07138118041232872
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# -----
# AUC-PR all: 0.11610292066638606
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# ----------
# AUC-PR all: 0.08172525427940583
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
#
# AUC-PR all: 0.11480794482124955
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation--------
# AUC-PR all: 0.38278633820337615
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
#
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1 ends:
# KR1 ends:KR1 ends:
#
# -----
# AUC-PR all: 0.07644062840019139
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# -----
# AUC-PR all: 0.3448911719000075
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.4111693332026676
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----KR1 ends:
# AUC-PR all: 0.11247112695413694
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
#
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1 ends:
# proportion of ground truth:proportion of ground truth: 0.025841571088004847
# ---evaluation---
#  0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.09922794810254944
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.09172573732803699
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends: 0.025841571088004847
# ---evaluation---
#
# -----
# AUC-PR all: 0.08091126839958612
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.43148988920600195
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----proportion of ground truth: 0.025841571088004847
# ---evaluation---
#
# AUC-PR all: 0.07135408868811696
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.44392764048174177
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07154451650462824
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# -----
# AUC-PR all: 0.09300354586103524
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.3523213818474976
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.44392764048174177
# Fold: 4
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size:target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
#  115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index:First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  [504 103 562 453 183  37 100 429 166 376]
#
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115target size:
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---KR1 starts:
#
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 starts:
# KR1 ends:
# KR1 ends:KR1 ends:
#
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR1 ends:
# -----proportion of ground truth:
# AUC-PR all: 0.117013821935384
# -----
# ------ lmd1: 0.026396017922455096
# ---evaluation---
#  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1 ends:KR1 ends:
#
# KR1 ends:
# KR1 starts:
# KR1 ends:
# proportion of ground truth:KR1 ends:
#  0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR1 starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: 0.3558350654798895
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.09230991710107914
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
#  0.42981216285645074
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:proportion of ground truth: 0.026396017922455096
# ---evaluation---
#
# KR1 ends:KR1 ends:
#
# -----
# AUC-PR all: 0.08450025452977905
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# proportion of ground truth:-----
# AUC-PR all: 0.08449037917944563
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.11829105212147074
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
#  0.026396017922455096
# ---evaluation---
# KR1 ends:
# -----
# AUC-PR all: -----
# AUC-PR all: 0.07538501496651973
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.0940922015910102
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# 0.38923595956268847
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4270854972639441
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07573760081897106
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.11787639124050067
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10334586141837607
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07575110134754669
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.34702829134274726
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# KR1 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.07853964984329809
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR1 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4449297809124555
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4449297809124555
# --- tuning end ---

# %% [markdown]
# Running CV for Chem. The best hyperparameters are $\lambda=1, \sigma=10$.

# %%
main(method_option="KR2",Validation="cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  0.025335269496882206
# ---evaluation---
# KR2 ends:
# KR2 ends:KR2 ends:KR2 ends:
#
#
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.3357663876681959
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.26204926205899765
# ----- 0.025335269496882206
# ---evaluation---
#
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.1501278585406341
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.26204926205899765
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.1502492244773262
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.4030175780433751
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# ----------KR2 ends:
# AUC-PR all: 0.3646693709793347
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
#
# KR2 ends:
# KR2 ends:
#
# proportion of ground truth:AUC-PR all: 0.3938623047729999
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
#  0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.15269190268272378
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.374584417744702
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.26204926205899765
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.26204926205899765
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.15034379446932006
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.15019707735910093
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.15021116470500304
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.26204926205899765
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.26204926205899765
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.33909524327479235
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4030175780433751
# Fold: 1
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
# KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth:KR2 starts:
# KR2 ends: 0.025361671727094123
# ---evaluation---
#
# KR2 ends:
# KR2 starts:
# KR2 starts:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR2 ends:KR2 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
#
# KR2 ends:
# proportion of ground truth:KR2 starts:
#  0.025361671727094123
# ---evaluation---
# KR2 ends:
# KR2 ends:proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
#
# -----
# AUC-PR all: 0.2501782169340853
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.3847518371343769
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.3604845628646083
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.3908461576061987
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.2505426986715666
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.13713388169819746
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.3297930299763844
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.13630610942471494
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3121162948347688
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.2507442694637685
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.13716117774777786
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.2501782169340853
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# -----
# AUC-PR all: 0.2507442694637685
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.13599584457991748
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.1361514184363761
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.346282713987983
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.2501782169340853
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.13625370282187843
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (10.0, 0.0, 10.0)
# AUPRC:  0.3908461576061987
# Fold: 2
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size:target size: 115
# First few target index: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478] [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 ends:
# KR2 ends:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR2 starts:
# KR2 ends:
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth:-----
# AUC-PR all: 0.23328620270379485
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
#  0.02614131405452837
# ---evaluation---
# KR2 starts:
# KR2 ends:
# KR2 ends:KR2 ends:
#
# KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.15818704117559762
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# KR2 ends:proportion of ground truth: 0.02614131405452837
# ---evaluation---
#
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.23328620270379485
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth:KR2 ends:
# ----- 0.02614131405452837
# ---evaluation---
# KR2 ends:
# KR2 ends:
#
# AUC-PR all: 0.3581098742307158
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0KR2 ends:
#  -----
# AUC-PR all: 0.23255562251280051
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# ------
# -----
# AUC-PR all: 0.1559199922038094
# -----
# ------ lmd1:  10.0 lmd1:  0.0 KR2 ends:
# sigma:  1.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# -----
# AUC-PR all: 0.23255562251280051
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# AUC-PR all: 0.23255562251280051
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.32896405220784364
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.3885398784400898
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0-----
# AUC-PR all: 0.23310286828267368
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
#  ------
# -----
# AUC-PR all: 0.1547944945461568
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.15478843486429883
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.383628288328479
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.16413502013035713
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3227639617949675
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# -----proportion of ground truth:
# AUC-PR all: 0.16208476898803337
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
#  0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.35661743274921687
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.3885398784400898
# Fold: 3
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# First few target index:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#  115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:KR2 starts:
#
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR2 ends:
# KR2 ends:KR2 ends:proportion of ground truth: 0.025841571088004847
# ---evaluation---
#
#
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.025841571088004847
# KR2 ends:
# ---evaluation---
# KR2 ends:KR2 ends:
#
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.18305348730739102
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---KR2 ends:
# KR2 ends:
#
# -----
# AUC-PR all: 0.18305348730739102
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR2 ends:
# proportion of ground truth:KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
#  0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.3675112634082802
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.18278627389772825
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.38333251195621265
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR2 ends:-----
# KR2 ends:-----
# AUC-PR all: 0.1752639415439147
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# AUC-PR all:
# -----
# AUC-PR all: 0.34828826597054874
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#  0.18302248323350484proportion of ground truth: 0.025841571088004847
# ---evaluation---
#
#
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# ----------
#
# AUC-PR all: 0.18278627389772825
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# AUC-PR all: 0.1748640841649916
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3999798103414477-----
# AUC-PR all: 0.18278627389772825
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
#
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.41037371542718415
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# -----
# AUC-PR all: 0.18384342050866104
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# AUC-PR all: 0.33774051752153234
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.1748871604012054
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.18150759724439267
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.18520483916557418
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.41037371542718415
# Fold: 4
# target size:target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  115target size:target size: 115
# First few target index:target size: 115
# First few target index:  115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size:target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 starts:
# KR2 ends:
# KR2 starts:
# proportion of ground truth:KR2 ends:
#  0.026396017922455096
# ---evaluation---
# KR2 ends:KR2 starts:
#
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR2 ends:
# KR2 ends:
# KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR2 ends:
# KR2 ends:
# KR2 ends:
# KR2 ends:KR2 starts:
#
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.39683109346583284
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: proportion of ground truth: 0.026396017922455096
# 0.026396017922455096
# ---evaluation---
# ---evaluation---
# KR2 ends:
# proportion of ground truth:KR2 ends:
#  0.026396017922455096
# KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR2 ends:
# proportion of ground truth:KR2 ends:
#  0.026396017922455096
# ---evaluation---
# proportion of ground truth:----------
# AUC-PR all: 0.41188739142574404
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
#
#  0.026396017922455096
# ---evaluation---
# proportion of ground truth:AUC-PR all: 0.3404804667384629
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#  0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.13817070705797047
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR2 ends:
# -----
# AUC-PR all: 0.14274385042145635
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1502637979652674
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# KR2 ends:
# -----
# AUC-PR all: 0.14676090904799494
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.1383487322543579
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.1383487322543579
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.14278920184606197
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.13817070705797047
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.13817070705797047
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: proportion of ground truth:0.33883533800554855
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
#  0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.3818399154499539
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.14300433656910128
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.15158853472922001
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.367854032765231
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.13826515013533444
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.41188739142574404
# --- tuning end ---

# %% [markdown]
# Running CV for DGI and Chem (multiple kernels). The best hyperparameters are $\lambda_{1}=0.1, \lambda_{2}=1, \sigma=10$.

# %%
main(method_option="MKR",Validation="cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# target size:target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index:115 [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337] 115
# First few target index:
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# target size:First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# target size: 115
# First few target index: First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
#
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: First few mask index: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]target size:
#  115target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:
#
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:proportion of ground truth:-----MKR starts:
#
#
# AUC-PR all: 0.08929125793144153
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.11937624016423468
# -----
# ------ lmd1:  0.01 lmd1:  100.0 sigma:  1.0 MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR ends:MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:
#  MKR starts:
# 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.3518573020217553
# -----
# ------ lmd1:  0.01 MKR starts:
# lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.12005624366596562
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth:First few mask index:proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.08932084612482671
# -----
# ------ lmd1:  0.1 lmd1:  0.025335269496882206
# ---evaluation---
#  10.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# MKR starts:
# -----
# AUC-PR all: 0.08967439087230333
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  0.1 ------
# target size:MKR ends:MKR ends:
#
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# MKR starts:
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:MKR ends:
#
# proportion of ground truth:MKR starts:
# MKR ends:-----
# AUC-PR all: 0.08888809966178497
# -----
# ------ lmd1:  1.0 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index:MKR starts:
#  [384 293 396 263  31 466 141 431  32 337]
#  0.025335269496882206
# ---evaluation---
#
# MKR starts:
# -----
# AUC-PR all: 0.39504219472510893
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  10.0 ------
# target size: 115
# First few target index:proportion of ground truth: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  -----
# AUC-PR all: 0.13193476007118599
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# 0.025335269496882206
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR starts:
# proportion of ground truth:MKR starts:
# -----
# AUC-PR all: 0.4201746999891191
# -----
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
#  proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.38945640735773696
# -----
# ------ lmd1:  0.01 lmd1:  100.0 sigma:  10.0 ------
# target size: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:-----
# AUC-PR all: 0.08962385309616808
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# MKR starts:
# MKR starts:
# AUC-PR all: 0.12254722028126415MKR starts:
# MKR ends:MKR starts:
#
#
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  1.0 ------
# target size:
#  115-----
# AUC-PR all: 0.12613989100913123
# -----
# ------ lmd1:  1.0 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.11977153462240507
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma: proportion of ground truth:MKR ends:MKR ends:
#  1.0 ------
# target size: 115
# First few target index: 0.025335269496882206
# ---evaluation---
#
#  [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# MKR starts:
# proportion of ground truth:---evaluation---
# -----
# AUC-PR all: 0.12159680857866506
# -----
# ------ lmd1:  0.1 lmd1:  -----
# AUC-PR all: 0.12209172638464612
# -----
# 1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR starts:
# -----
# AUC-PR all: 0.025335269496882206
# ---evaluation---
# ------ lmd1:  0.1 lmd1:  100.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  0.08929413780762033
# -----
# ------ lmd1:  0.1 lmd1:  100.0MKR ends:
# -----
# AUC-PR all: 0.1201370660550692
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08912144028047253
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.4363064233069144
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index:MKR ends:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206 [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR starts:
#
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.08491811723899548
# -----proportion of ground truth: 0.025335269496882206
# ------ lmd1:  1.0 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# ---evaluation---
# -----
# AUC-PR all: 0.4282645925989556
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.08896425496793955
# -----
# ------ lmd1:  0.01 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# proportion of ground truth:-----
# AUC-PR all: 0.08966005013037333
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends: 0.025335269496882206
# ---evaluation---
# MKR ends:
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# -----
# AUC-PR all: 0.35963050517453193
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08894291096516338
# -----
# ------ lmd1:  0.01 lmd1:  100.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----proportion of ground truth: 0.025335269496882206
#
# AUC-PR all: 0.3539085739194311
# -----
# ------ lmd1:  1.0 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.12693164871582935
# ---evaluation--------
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# -----
# AUC-PR all: 0.38106208271808983
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:MKR starts:
# -----
# AUC-PR all: 0.38851729390162987
# -----
# ------ lmd1:  0.01 lmd1:  1000.0 sigma:  10.0 ------
# target size: 115
# First few target index:
# [384 293 396 263  31 466 141 431  32 337]MKR starts:
# MKR starts:
#
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR starts:
# MKR ends:
# MKR ends:
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:MKR ends:
# MKR starts:
#  0.025335269496882206
# ---evaluation---
# MKR ends:MKR ends:
# MKR starts:
# -----
# AUC-PR all: 0.09138332643629565
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index:proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
#
# -----
# AUC-PR all: 0.08657379632029552
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.12164357887146697
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: proportion of ground truth: 0.025335269496882206
# ---evaluation---
# 0.025335269496882206
# ---evaluation---
# proportion of ground truth:MKR starts:
# -----
# AUC-PR all: 0.39664068515160916
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  10.0 ------
# target size: 115
# First few target index:  0.025335269496882206
# ---evaluation---
# [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# -----
# AUC-PR all: 0.4227289367721601
# -----
# ------ lmd1:  0.1 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth:MKR starts:
#  0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.43041459307445284
# -----
# ------ lmd1:  -----
# AUC-PR all: 0.12722065068511743
# -----
# ------ lmd1:  0.11.0 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth:proportion of ground truth:  0.025335269496882206
# ---evaluation---
# 0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR starts:
# -----
# AUC-PR all: 0.1199542245457534
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR starts:
# MKR starts:
# -----
# AUC-PR all: 0.08956292550531314
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# MKR ends:
# MKR starts:
# proportion of ground truth:MKR ends:
# MKR starts:
#  0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.1190387994168279
# -----proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all:
#  0.1233125651274083
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# ------ lmd1:  0.01 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.08657254905915227
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.4348285837384843
# ----------
# AUC-PR all: 0.11789769050303398
# -----
# ------ lmd1:  1.0 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
#
# ------ lmd1:  1.0 lmd1:  1.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# -----MKR ends:
# -----
# AUC-PR all: 0.13128040028219995
# -----
# ------ lmd1:  0.1 lmd1:  0.1
# AUC-PR all: 0.08902597220422984
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# sigma: MKR ends:MKR starts:
#
#  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08925853707885167
# -----
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# -----
# AUC-PR all: 0.4264144360091847
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  10.0 ------
# target size: proportion of ground truth:----- 0.025335269496882206
# 115
# AUC-PR all: 0.39900751022563713
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  10.0 ------
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# ---evaluation---
#
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# MKR starts:
# MKR starts:
# -----MKR starts:
# -----
# AUC-PR all: 0.08941691535719383
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# MKR ends:
# proportion of ground truth:AUC-PR all:MKR ends:
#   0.11600775767971552
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# 0.025335269496882206
# ---evaluation---
# -----
# MKR starts:
# AUC-PR all: 0.0893924791132284
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  0.1 ------proportion of ground truth:MKR ends:
#  0.025335269496882206
# ---evaluation---
#
# -----
# AUC-PR all: 0.3920546999339751
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.3872377565891911
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.10878216729546872
# -----MKR ends:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR starts:
#
# -----
# AUC-PR all: 0.12248523674886111
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# proportion of ground truth: ------ lmd1:  10.0 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# MKR ends:
# 0.025335269496882206MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
#
# ---evaluation---
# MKR starts:
# MKR ends:proportion of ground truth:MKR ends:MKR ends:
#
#
#  0.025335269496882206
# ---evaluation---
# ----------
# AUC-PR all: 0.41808750460646493
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#
# AUC-PR all: 0.08941344591459283
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  0.1 ------
# MKR starts:
# MKR starts:
# MKR ends:
# proportion of ground truth:proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  -----
# AUC-PR all: 0.0866013145772622
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  0.1 ------
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# 0.025335269496882206
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.427288588138819
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  10.0 ------
# proportion of ground truth: MKR starts:
# 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08029412880771611
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3481258026002893
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma: MKR ends:
# -----
# AUC-PR all: 0.11674118477488424
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  1.0 ------
#  10.0 ------
# -----
# AUC-PR all: 0.3461498255442941
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  10.0-----
# AUC-PR all: 0.10461434997245894
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  1.0 ------
#  ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:
# MKR ends:
# MKR starts:
# -----proportion of ground truth:-----
# AUC-PR all: 0.11921745512397751
# -----
# ------ lmd1:  1.0 lmd1:  1000.0
# AUC-PR all: 0.08053957874467116
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  0.1 ------
# sigma:  1.0  0.025335269496882206
# ---evaluation---
# ------
# -----
# AUC-PR all: 0.1184298159151836
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  1.0 ------MKR starts:
#
# proportion of ground truth:MKR starts:
# MKR starts:proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  0.025335269496882206
# ---evaluation---
#
# -----
# AUC-PR all: 0.08959509417098444
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  0.1 ------
# MKR starts:
# MKR starts:
# MKR ends:
# MKR ends:MKR starts:
#
# proportion of ground truth:MKR ends:
#  0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.3987263816134611
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  10.0 ------
# MKR starts:
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.3827011720177741
# -----
# MKR ends:
# -----
# AUC-PR all: 0.07982999384734879
# -----
# ------ lmd1:  100.0 lmd1:  100.0 MKR ends:
# sigma:  0.1 ------
# MKR ends:
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  10.0 ------
# MKR ends:
# -----
# AUC-PR all:MKR starts:
# MKR ends:
#  0.4126827860337578
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  10.0 ------
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08937769125677411
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  0.1 ------
# MKR starts:
# proportion of ground truth:MKR starts:
#  0.025335269496882206MKR ends:
# MKR ends:
#
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.08927847100018171
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.42219432964314496
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.025335269496882206 0.025335269496882206
# ---evaluation---
#
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.07964268362275748
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  0.1 ------
# -----
# AUC-PR all: -----
# AUC-PR all: 0.4063368947888233
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  10.0 ------
# 0.11494057243061993
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.10319350788970398
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  1.0 ------
# MKR starts:
# MKR ends:
# MKR starts:
# MKR ends:
# -----
# AUC-PR all: 0.08031345959539238
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  0.1 ------
# MKR ends:
# -----
# AUC-PR all: 0.12325520535972385
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  1.0 ------
# MKR ends:
# MKR ends:-----
# MKR starts:
# MKR starts:
# -----
# AUC-PR all: 0.08933589562908201
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  0.1 ------
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
#
# AUC-PR all: 0.1344399572768262
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08943202695133602
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.40951231499625956
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# MKR ends:
# -----
# AUC-PR all:MKR ends:
# MKR ends:
#  MKR ends:
# 0.1206063186878911
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  1.0 ------
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.0892483598594215
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  0.1 ------
# proportion of ground truth:proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  0.025335269496882206
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.38039119321317505
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  10.0 ------
# -----
# -----
# AUC-PR all: 0.08928369071299723
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10658482014578977
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  1.0 ------
# proportion of ground truth:proportion of ground truth: 0.025335269496882206
# ---evaluation---
# MKR ends:
# AUC-PR all: 0.3429482362076962
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  10.0 ------
#  0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.4007509709531392
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.3755907494678501
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07984376147366937
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  0.1 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.0982199494387273
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  1.0 ------
# -----
# AUC-PR all:-----
# AUC-PR all: 0.14428601900523244
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  1.0 ------
#  0.13356526988148365
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  1.0 ------
# -----MKR ends:
# AUC-PR all: 0.3822889859980809
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  10.0 ------
# MKR ends:
#
# MKR ends:
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.36359485559649535
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  10.0 ------
# proportion of ground truth:-----
# AUC-PR all: 0.3715663500886957
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
#  0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08929703052636626
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.396268048625106
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08939734767885818
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09548568525094783
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  1.0 ------
# -----MKR ends:
# AUC-PR all:
#  0.1044766550881297
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  1.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.09633226765955623
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 10.0, 10.0)
# AUPRC:  0.4363064233069144
# Fold: 1
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size:target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size:115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size:target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
#
#  115target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index:
#  First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# 115First few mask index:
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# [259 223 528 422 492 452   3 390 268 331]
# target size: 115target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
#
# First few target index:First few mask index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  [259 223 528 422 492 452   3 390 268 331]target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#
# target size:target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  target size:115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:MKR starts:
#
# MKR starts:
# MKR starts:
# MKR starts:MKR starts:
#
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR ends:
# MKR starts:
# proportion of ground truth:-----
# AUC-PR all: 0.07460270109972397
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  0.1 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  MKR starts:
# 0.025361671727094123
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.025361671727094123
# ---evaluation---
#  0.025361671727094123
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR starts:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR ends:
# MKR starts:
# MKR ends:
# MKR starts:
# proportion of ground truth:-----
# AUC-PR all: 0.10678278557570658
# -----
# ------ lmd1:  0.1 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  0.025361671727094123MKR ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR ends:
# MKR starts:
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.07531318116789512
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  0.1 ------
# target size:
# 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# MKR ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: proportion of ground truth:proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.10647040846696376
# -----
# ------ lmd1:  0.01 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# 0.34066702095413565
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  10.0 ------MKR ends:
#
# MKR starts:
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# MKR starts:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR starts:
# -----
# AUC-PR all: 0.09645159193882667
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR ends:MKR ends:
#
# MKR starts:
# MKR ends:MKR ends:
# -----
# AUC-PR all: 0.33892147585511956
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index:
# MKR ends:MKR ends:
# proportion of ground truth: 0.025361671727094123
#
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# ---evaluation--------
#  [259 223 528 422 492 452   3 390 268 331]
# MKR ends:AUC-PR all: 0.06889894791816105
# -----
# ------ lmd1:  1.0 lmd1:  1.0 sigma:  0.1 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# proportion of ground truth:MKR ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
#
# 0.025361671727094123
# ---evaluation---
#
# MKR ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.10901407738153579
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  1.0 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# MKR ends:-----
# AUC-PR all: 0.4440058360951398
# -----
# ------ lmd1:  1.0 lmd1:  10.0proportion of ground truth: 0.025361671727094123
# ---evaluation---
#  sigma:  -----
# AUC-PR all: 0.07506039535889936
# -----
# 10.0 ------
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#
# ------ lmd1:  proportion of ground truth:proportion of ground truth:proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.4036784655124916
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# ...
# -----
# ------ lmd1:  0.1 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#
# -----
# ------ lmd1:  0.1 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:
# -----
# AUC-PR all: 0.4218869651773261
# -----
# ------ lmd1:  0.01 lmd1:  0.1 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR ends:
# MKR ends:
# --------evaluation---
#
# AUC-PR all: 0.08155085535851732
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  0.1 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# -----
# AUC-PR all: 0.08306463703390175
# -----
# ------ lmd1:  0.1 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# -----
# AUC-PR all: 0.4308094336503486-----
# AUC-PR all: 0.43565204239551647
# -----
# AUC-PR all: 0.38202113243726965
# -----
# -----
# ------ lmd1:  0.01 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# -----
# MKR ends:
# -----
# AUC-PR all: 0.08830394860558628
# -----
# ------ lmd1:
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  ------ lmd1: 10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  0.1 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# 0.01 proportion of ground truth: 0.026396017922455096
# ---evaluation---
# lmd1:  1000.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# -----
# AUC-PR all: 0.4474495490410516
# -----
# ------ lmd1:  0.1 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
# -----
# AUC-PR all: 0.44587977223192105-----
# -----
# AUC-PR all: 0.0831742293056609
# -----
# ------ lmd1:  1.0 lmd1:  0.1 sigma:  0.1 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# AUC-PR all:
#  proportion of ground truth: 0.026396017922455096
# ---evaluation---
# 0.43605680755618825
# ----------
# ------ lmd1:  1.0 lmd1:  100.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#
# ------ lmd1:  0.1 lmd1:  1000.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
# MKR starts:
# MKR starts:
# -----
# AUC-PR all: 0.4316054644378086
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  10.0 ------
# target size:-----
# AUC-PR all: 0.44552965390500127
# -----
# ------ lmd1:  1.0 lmd1:  10.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
#  115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR ends:-----
# AUC-PR all: 0.11726227657705013
# -----
# ------ lmd1:  1.0 lmd1:  1.0
#  sigma:  1.0 ------
# target size: -----
# AUC-PR all: 0.11932940659161806
# -----
# ------ lmd1:  0.01 lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: MKR ends:
# [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
# proportion of ground truth: 0.026396017922455096
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# ---evaluation---
# -----
# AUC-PR all: 0.4559671476992742
# -----
# ------ lmd1:  0.1MKR starts:
# MKR starts:
#  lmd1:  1.0 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# -----
# AUC-PR all: 0.11930315379238998
# -----
# ------ lmd1:  0.01 lmd1:  1.0 sigma:  1.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR ends:MKR ends:
#
# MKR starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.08331465658912748
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  0.1 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR starts:
# MKR ends:MKR ends:
#
# -----
# AUC-PR all: 0.09240474678192784
# -----
# ------ lmd1:  10.0MKR starts:
#  lmd1:  0.01 sigma:  1.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# proportion of ground truth:MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
#  0.026396017922455096
# ---evaluation---
# proportion of ground truth:MKR starts:
#  0.026396017922455096
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:
# MKR ends:
# MKR starts:
# MKR ends:
# -----
# AUC-PR all: 0.3625861501372474
# -----
# ------ lmd1:  10.0 lmd1:  0.01 sigma:  10.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR ends:MKR starts:
# MKR ends:
# -----MKR ends:proportion of ground truth:
# AUC-PR all: 0.10707325761059003
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  1.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  0.026396017922455096
# ---evaluation---
#
# MKR starts:
#
# -----
# AUC-PR all: 0.11842995936203055
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  1.0 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# proportion of ground truth:proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.08155195614757518
# -----
# ------ lmd1:  1.0 lmd1:  1000.0 sigma:  0.1 ------
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# MKR starts:
# proportion of ground truth:MKR starts:
#  0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
#  0.026396017922455096
# ---evaluation---
# MKR starts:
# MKR starts:
# MKR starts:
# proportion of ground truth:-----
# AUC-PR all: 0.0934575153307265
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  1.0 ------
#  MKR ends:MKR ends:MKR starts:
#
#
# -----
# AUC-PR all: 0.0832919240133879
# -----
# 0.026396017922455096
# ---evaluation---
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  0.1 ------
# MKR ends:MKR starts:
#
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# MKR starts:
# proportion of ground truth:proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.3764758891208368
# -----
# ------ lmd1:  100.0AUC-PR all: 0.08332812846260605
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  0.1 ------
# -----
# AUC-PR all: 0.4208155445361474
# -----
# ------ lmd1:  lmd1:   10.0 lmd1:  10.0 sigma:  10.0 ------
# 100.0 sigma:  10.0 ------
#  0.026396017922455096
# ---evaluation---
# MKR ends:
# MKR ends:-----
# AUC-PR all: 0.105343510515543
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  1.0 ------
#
# proportion of ground truth:proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.40327546889735055
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  10.0 ------
#  MKR ends:
# 0.026396017922455096
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR starts:
# -----
# proportion of ground truth:AUC-PR all: 0.3615926788762188
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  10.0 ------
#  0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.0796835458114098
# -----
# ------ lmd1:  10.0 lmd1:  100.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:MKR ends:
#
# -----
# AUC-PR all: 0.40395113276682515
# -----
# ------ lmd1:  10.0 lmd1:  0.1 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08334433563638122
# -----MKR starts:
# MKR starts:
#
# ------ lmd1:  100.0 proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR starts:lmd1: -----
# AUC-PR all: 0.07967851174687243
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  0.1 ------
#  proportion of ground truth: 0.026396017922455096
# ---evaluation---
# 0.01 sigma:  0.1 ------
# -----MKR ends:
#
#
# AUC-PR all: 0.43244032235926283
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  10.0 ------
# MKR starts:
# MKR starts:
# -----
# AUC-PR all: 0.09978480086599262
# -----
# ------ lmd1:  10.0 lmd1:  1.0 sigma:  1.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR starts:
# MKR ends:
# MKR ends:
# -----
# AUC-PR all: 0.08324390625040265
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  0.1 ------
# MKR ends:
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:
# MKR starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:MKR ends:
#
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: -----
# AUC-PR all: 0.0928307113720316
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  1.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# 0.026396017922455096
# MKR starts:
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.358758205293023
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  10.0 ------
# MKR starts:
# -----
# AUC-PR all: 0.08333751262419822
# -----
# ------ lmd1:  100.0 lmd1:  0.1 sigma:  0.1 ------
# MKR ends:-----
# AUC-PR all: 0.09203871722378101-----
#
#
# MKR ends:
# MKR starts:
# MKR starts:
# AUC-PR all: 0.083291601263674
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  0.1 MKR starts:
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  1.0 ------
# MKR ends:
# ------
# proportion of ground truth: 0.026396017922455096proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
#
# AUC-PR all: 0.10438428062419386
# -----
# ------ lmd1:  10.0 lmd1:  1000.0---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
#  sigma:  1.0 ------
# MKR starts:
# -----
# AUC-PR all: 0.09648802158409964
# -----
# ------ lmd1:  -----
# AUC-PR all: 0.10567065661399887
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  1.0 ------
# 1000.0 lmd1:  0.1 sigma:  1.0 ------
# -----
# AUC-PR all: 0.39835315591121156
# -----
# ------ lmd1:  -----100.0 lmd1:  0.1 sigma:  10.0 ------
#
# AUC-PR all: 0.39328038692896705
# -----
# ------ lmd1:  10.0 lmd1:  1000.0 sigma:  10.0 ------
# MKR starts:
# -----
# AUC-PR all: 0.07999364794236151MKR ends:
#
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.0784707619690817
# -----
# ------ lmd1:  10.0 lmd1:  10.0 sigma:  0.1 ------
# MKR starts:
# MKR starts:
# MKR starts:
# MKR ends:-----
# AUC-PR all: 0.07870308858690475
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  0.1
# MKR ends: ------
# MKR starts:
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.026396017922455096
#
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.026396017922455096
# ---evaluation---
#  0.026396017922455096
# -----
# AUC-PR all: 0.42268065650233355
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  10.0 ---evaluation---
# MKR starts:
# ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.08334239800851098
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  0.1 ------
# MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.026396017922455096proportion of ground truth: 0.026396017922455096
# ---evaluation---
#
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: proportion of ground truth: proportion of ground truth: 0.026396017922455096
# ---evaluation---
# 0.026396017922455096
# ---evaluation---
# 0.08329253036657965
# -----
# ------ lmd1:  1000.0 lmd1:  -----
# AUC-PR all: 0.08336170674753665
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  0.1 ------
# 1.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3926412109343327
# -----
# ------ lmd1:  1000.0 lmd1:  0.1 sigma:  10.0 ------
# MKR ends:
# MKR ends:MKR ends:
#
# -----
# AUC-PR all: 0.40289436434871057
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.0786635627905529
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:proportion of ground truth: 0.026396017922455096
# ---evaluation---
#
# -----
# AUC-PR all: 0.09798416999320197
# -----
# ------ lmd1:  100.0 lmd1:  10.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09121742896376835
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  1.0 ------
# MKR ends:proportion of ground truth:
#  0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.09243320662018632
# -----
# ------ lmd1:  100.0 lmd1:  1.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.35333213974755884
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  10.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.08323685543237358
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.09719706077149268
# -----
# ------ lmd1:  100.0 lmd1:  100.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09554795839661706
# -----
# ------ lmd1:  100.0 lmd1:  1000.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3984145264982753
# -----
# ------ lmd1:  1000.0 lmd1:  10.0 sigma:  10.0 ------
# MKR ends:
# MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# MKR ends:
# -----
# AUC-PR all: 0.09653754807114506
# -----
# ------ lmd1:  100.0 lmd1:  0.01 sigma:  1.0 ------
# MKR ends:MKR ends:
#
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.34895738326808384
# -----
# ------ lmd1:  1000.0 lmd1:  0.01 sigma:  10.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4194565311527789
# -----
# ------ lmd1:  1000.0 lmd1:  1.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09512166636326844
# -----
# ------ lmd1:  1000.0 lmd1:  1000.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08323363714737947
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09666260676373686
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.36982761775167966
# -----
# ------ lmd1:  1000.0 lmd1:  100.0 sigma:  10.0 ------
# best hyperpar:  (0.1, 1.0, 10.0)
# AUPRC:  0.4559671476992742
# --- tuning end ---

# %% [markdown]
# Running CV for DGI and Chem (linear combination). The best hyperparameters are $\lambda=0.1, \sigma=10$

# %%
main(method_option="KR1&KR2",Validation="cv")
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# Fold: 0
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size:target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
#  115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# target size: 115
# First few target index: [384 293 396 263  31 466 141 431  32 337]
# First few mask index: [384 293 396 263  31 466 141 431  32 337]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
#
# KR1&KR2 ends:
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.39893432313763827
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.35702530670737004
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.10709886191654841
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.4330918003215146
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:KR1&KR2 ends:
# proportion of ground truth:KR1&KR2 ends: 0.025335269496882206
# ---evaluation---
#
#
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.36889992031061997
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth:KR1&KR2 ends:
#  0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----proportion of ground truth:
# AUC-PR all: 0.08117771007816674
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
#  0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08085222034258963
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.42903984176396814
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1&KR2 ends:
# -----
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# AUC-PR all: 0.1220480489524834
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.3925355314077874
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.09981686694979451
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025335269496882206
# ---evaluation---
# -----
# AUC-PR all: 0.08084512124813018
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10065351156632113
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.12968607099282062
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.09035276127362526
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.08932409250770756
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.09043746509520682
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.12897362323403083
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.4330918003215146
# Fold: 1
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size:target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# [259 223 528 422 492 452   3 390 268 331]
# target size:target size:
# 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]target size:target size: target size: 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# 115 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#
# First few target index: [259 223 528 422 492 452   3 390 268 331] 115
# First few target index: [259 223 528 422 492 452   3 390 268 331]
#
# First few mask index:
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
# First few mask index: [259 223 528 422 492 452   3 390 268 331]
#  [259 223 528 422 492 452   3 390 268 331]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.025361671727094123proportion of ground truth: 0.025361671727094123
# ---evaluation---
#
# ---evaluation---
# proportion of ground truth:proportion of ground truth: 0.025361671727094123
# ---evaluation---
#  0.025361671727094123
# ---evaluation---
# proportion of ground truth: KR1&KR2 ends:
# 0.025361671727094123
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.10650152086905454
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.07305406902336073
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.34929959980349723
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# -----
# AUC-PR all: 0.06755614073016138
# AUC-PR all: 0.10610339159259709
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.08857093165139895
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# -----KR1&KR2 ends:
# proportion of ground truth:
# 0.025361671727094123AUC-PR all: 0.37570449893604807
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
#
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:proportion of ground truth: 0.025361671727094123
# ---evaluation---
#
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.4122179224219449
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.3614642123526578
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.3959033486497125
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.07313517516610822
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.0673558087703799
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07164032795804408
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.08363018399966884
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.10071896398586515
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.06736357101511815
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025361671727094123
# ---evaluation---
# -----
# AUC-PR all: 0.43141612322693706
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08300354698024763
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (1.0, 0.0, 10.0)
# AUPRC:  0.43141612322693706
# Fold: 2
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#
# First few target index:target size: 115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  115
# First few target index: [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
#  [144 278  36  84  99 379 361 173 355 478]
# First few mask index: [144 278  36  84  99 379 361 173 355 478]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
#
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.08179748992110382
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----KR1&KR2 ends:
#
# AUC-PR all: 0.08812575855764207
# -----
# ------ lmd1:  10.0 -----
# AUC-PR all: 0.10127375692474658
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.08174212708102183
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.38836981935758086
# -----
# ------ lmd1:  proportion of ground truth:KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# 10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08241846380500382
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.42792195873924177
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07360097683559214
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.07939753432397273
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.4296849719296887
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08308628235812457
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.11309917397577468
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.4078375980518344
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----proportion of ground truth: 0.02614131405452837
# ---evaluation---
#
# AUC-PR all: 0.07343194675274566
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.3435202070332128
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.07339846602823272
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.02614131405452837
# ---evaluation---
# -----
# AUC-PR all: 0.35576675651371653
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.11106959333225191
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4296849719296887
# Fold: 3
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size:target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index:  [386 149 145  47  29 286 102  15   2 298]
# target size: 115
# 115
# First few target index: target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# [386 149 145  47  29 286 102  15   2 298]target size: 115
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
#
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# First few target index: [386 149 145  47  29 286 102  15   2 298]
# First few mask index: [386 149 145  47  29 286 102  15   2 298]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 ends:KR1&KR2 starts:
# proportion of ground truth:KR1&KR2 ends:
# KR1&KR2 ends:
# KR1&KR2 starts:
#
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
#  0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.09208458412561032
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.08613420462481954
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.10002089513731409
# -----
# ------ lmd1:  1000.0 lmd1: KR1&KR2 ends:
#  0.0 sigma: -----
# AUC-PR all: 0.3591442278110703 1.0 ------
#
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.40830889261591286
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08623869051461366
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.1257985985680809
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.08612348962652078
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10769546772483227
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth:proportion of ground truth: 0.025841571088004847
# ---evaluation---
#  0.025841571088004847
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
#
# -----
# AUC-PR all: 0.09023318156436314
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.10097472823220957
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.44394246336157095
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09213534002692585
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.12516102838609766
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.3947431782802997
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.11964805960239998
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# proportion of ground truth: 0.025841571088004847
# ---evaluation---
# -----
# AUC-PR all: 0.44089730382413983
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.34605757944882615
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.44394246336157095
# Fold: 4
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: target size: 115
# First few target index:target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#  [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# 115target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
#
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# target size: 115
# First few target index: [504 103 562 453 183  37 100 429 166 376]
# First few mask index: [504 103 562 453 183  37 100 429 166 376]
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:KR1&KR2 starts:
# KR1&KR2 starts:
#
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 starts:
# KR1&KR2 ends:KR1&KR2 ends:KR1&KR2 ends:
#
#
# KR1&KR2 starts:
# KR1&KR2 ends:
# KR1&KR2 starts:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR1&KR2 ends:KR1&KR2 ends:
# proportion of ground truth: 0.026396017922455096
#
# ---evaluation---
# KR1&KR2 ends:proportion of ground truth: 0.026396017922455096
# KR1&KR2 ends:
#
# proportion of ground truth:---evaluation---
#  0.026396017922455096
# ---evaluation---
# KR1&KR2 ends:
# KR1&KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.4507733185676005
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.08344319542151982
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096KR1&KR2 ends:
# KR1&KR2 ends:
#
# ---evaluation---
# KR1&KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.4431965526331105
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.36105034840232964
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08215928370522566
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:proportion of ground truth:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
#  0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.11530907113213074
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  1.0 ------
# proportion of ground truth: proportion of ground truth:0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.10439283665066484
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  1.0 ------
#  0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.09743163887707532
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  1.0 ------
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.11387374794885671
# -----
# ------ lmd1:  1.0 lmd1:  0.0 sigma:  1.0 ------
# -----
# AUC-PR all: 0.07853025564386287
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  0.1 ------
# -----
# AUC-PR all: 0.07853838267862547
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  0.1 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.34838707093477506
# -----
# ------ lmd1:  1000.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.09828331579700245
# -----
# ------ lmd1:  100.0 lmd1:  0.0 sigma:  1.0 ------
# ----------
# AUC-PR all: 0.11586252996573049
# -----
# ------ lmd1:  0.1 lmd1:  0.0 sigma:  1.0 ------
#
# AUC-PR all: 0.3973998685134748
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  10.0 ------
# -----
# AUC-PR all: 0.08345890549918651
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  0.1 ------
# KR1&KR2 ends:
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# KR1&KR2 ends:
# -----
# AUC-PR all: 0.4234998291997227
# -----
# ------ lmd1:  0.01 lmd1:  0.0 sigma:  10.0 ------
# proportion of ground truth: 0.026396017922455096
# ---evaluation---
# -----
# AUC-PR all: 0.0784427185851433
# -----
# ------ lmd1:  10.0 lmd1:  0.0 sigma:  0.1 ------
# best hyperpar:  (0.1, 0.0, 10.0)
# AUPRC:  0.4507733185676005
# --- tuning end ---

# %% [markdown]
# ### 2.3. Independent test set

# %%
main(method_option="KR1", Validation="Validation", l1=0.1, s=10)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  0.1 lmd1:  0 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.4112425624842458
# -----
# AUC-ROC all: 0.8887751461224314
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
main(method_option="KR2", Validation="Validation", l1=1.0, s=10)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  1.0 lmd1:  0 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.38059942289179904
# -----
# AUC-ROC all: 0.8812979242561445
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
main(method_option="MKR", Validation="Validation", l1=0.1, l2=1, s=10)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  0.1 lmd1:  1 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.4138175262320037
# -----
# AUC-ROC all: 0.8713086888710723
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
main(method_option="KR1&KR2", Validation="Validation", l1=0.1, s=10)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  0.1 lmd1:  0 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.4124813115885141
# -----
# AUC-ROC all: 0.8752913642985228
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
KR1_pr, KR1_roc = \
    main(method_option="KR1", Validation="plot", l1=0.1, s=10)             
KR1_pr.T.to_csv("Figs/KR1_pr.csv", index=False)
KR1_roc.T.to_csv("Figs/KR1_roc.csv", index=False)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  0.1 lmd1:  0 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# KR1 starts:
# KR1 ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.4112425624855005
# -----
# AUC-ROC all: 0.888775146158224
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
KR2_pr, KR2_roc = \
    main(method_option="KR2", Validation="plot", l1=1, s=10)
KR2_pr.T.to_csv("Figs/KR2_pr.csv", index=False)
KR2_roc.T.to_csv("Figs/KR2_roc.csv", index=False)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  1 lmd1:  0 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# KR2 starts:
# KR2 ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.38059942289179893
# -----
# AUC-ROC all: 0.8812979242561445
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
MKR_pr, MKR_roc = \
    main(method_option="MKR", Validation="plot", l1=0.1, l2=1, s=10)             
MKR_pr.T.to_csv("Figs/MKR_pr.csv", index=False)
MKR_roc.T.to_csv("Figs/MKR_roc.csv", index=False)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  0.1 lmd1:  1 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# MKR starts:
# MKR ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.4138175262320037
# -----
# AUC-ROC all: 0.8713086888710723
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0

# %%
KR1KR2_pr, KR1KR2_roc = \
    main(method_option="KR1&KR2", Validation="plot", l1=0.1, s=10)             
KR1KR2_pr.T.to_csv("Figs/KR1KR2_pr.csv", index=False)
KR1KR2_roc.T.to_csv("Figs/KR1KR2_roc.csv", index=False)
# Out:
# first few validation set idx:
# [2, 7, 12, 13, 17, 20, 26, 39, 45, 47]
# target size: 201
# ------ lmd1:  0.1 lmd1:  0 sigma:  10 ------
# First few target index: [ 4 11 14 27 32 34 35 37 41 47]
# First few mask index: [ 4 11 14 27 32 34 35 37 41 47]
# KR1&KR2 starts:
# KR1&KR2 ends:
# proportion of ground truth: 0.02256888445786783
# ---evaluation---
# -----
# AUC-PR all: 0.4124813116023129
# -----
# AUC-ROC all: 0.8752913643343151
# -----
# AUC-PR per drug: 0
# -----
# AUC-ROC per drug: 0
# -----
# AUC-ROC top N: 0
# -----
# AUC-PR top N: 0
# -----
# F1: 0
# -----
# Fmax 0
# -----
# Smin 0
